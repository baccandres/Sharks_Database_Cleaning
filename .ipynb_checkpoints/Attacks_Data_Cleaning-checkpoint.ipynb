# %%
import pandas as pd
import numpy as np
import seaborn as sns
import re
import random
import os
import cleaning_functions as cf

# %%
df_attacks = pd.read_csv("attacks.csv",encoding = "ISO-8859-1") #To load the data csv

# %%
df_attacks.shape
# Out:
# (25723, 24)

# %%
df_attacks.dtypes #weird variable formating
# Out:
# Case Number                object
# Date                       object
# Year                      float64
# Type                       object
# Country                    object
# Area                       object
# Location                   object
# Activity                   object
# Name                       object
# Sex                        object
# Age                        object
# Injury                     object
# Fatal (Y/N)                object
# Time                       object
# Species                    object
# Investigator or Source     object
# pdf                        object
# href formula               object
# href                       object
# Case Number.1              object
# Case Number.2              object
# original order            float64
# Unnamed: 22                object
# Unnamed: 23                object
# dtype: object

# %%
df_attacks.sample(5)
# Out:
#       Case Number         Date    Year        Type       Country  \
# 11070         NaN          NaN     NaN         NaN           NaN
# 11694         NaN          NaN     NaN         NaN           NaN
# 918    2011.05.29  29-May-2011  2011.0  Unprovoked  SOUTH AFRICA
# 14711         NaN          NaN     NaN         NaN           NaN
# 12301         NaN          NaN     NaN         NaN           NaN
#
#                         Area       Location Activity            Name Sex   \
# 11070                    NaN            NaN      NaN             NaN  NaN
# 11694                    NaN            NaN      NaN             NaN  NaN
# 918    Western Cape Province  Robberg Beach  Surfing  Clinton Nelson    M
# 14711                    NaN            NaN      NaN             NaN  NaN
# 12301                    NaN            NaN      NaN             NaN  NaN
#
#        ...     Species         Investigator or Source                    pdf  \
# 11070  ...          NaN                           NaN                    NaN
# 11694  ...          NaN                           NaN                    NaN
# 918    ...  White shark  The George Herald, 5/30/2011  2011.05.29-Nelson.pdf
# 14711  ...          NaN                           NaN                    NaN
# 12301  ...          NaN                           NaN                    NaN
#
#                                             href formula  \
# 11070                                                NaN
# 11694                                                NaN
# 918    http://sharkattackfile.net/spreadsheets/pdf_di...
# 14711                                                NaN
# 12301                                                NaN
#
#                                                     href Case Number.1  \
# 11070                                                NaN           NaN
# 11694                                                NaN           NaN
# 918    http://sharkattackfile.net/spreadsheets/pdf_di...    2011.05.29
# 14711                                                NaN           NaN
# 12301                                                NaN           NaN
#
#       Case Number.2 original order Unnamed: 22 Unnamed: 23
# 11070           NaN            NaN         NaN         NaN
# 11694           NaN            NaN         NaN         NaN
# 918      2011.05.29         5385.0         NaN         NaN
# 14711           NaN            NaN         NaN         NaN
# 12301           NaN            NaN         NaN         NaN
#
# [5 rows x 24 columns]

# %%
df_attacks['Unnamed: 22'].unique() #drop this column
# Out:
# array([nan, 'stopped here'], dtype=object)

# %%
df_attacks['Unnamed: 23'].unique() #drop this column
# Out:
# array([nan, 'Teramo', 'change filename'], dtype=object)

# %%
df_attacks['Case Number.2'].isin(df_attacks['Case Number.1']).value_counts()
#drop Case Number.2
# Out:
# True     25703
# False       20
# Name: Case Number.2, dtype: int64

# %%
df_attacks['Case Number.1'].isin(df_attacks['Case Number']).value_counts()
#drop Case Number.1
# Out:
# True     25700
# False       23
# Name: Case Number.1, dtype: int64

# %%
df_attacks['href formula'].isin(df_attacks['href']).value_counts()
#drop href formula
# Out:
# True     25664
# False       59
# Name: href formula, dtype: int64

# %%
#drop original order. Irrelevant for the analysis
#drop pdf. Irrelevant for the analysis (or not? Could get dates)

# %%
set(df_attacks['Date'].sample(n=50)) #explore Date format /drop, terrible formating
# Out:
# {'01-Nov-1974',
#  '01-Sep-1958',
#  '03-Jun-1984',
#  '06-Sep-1996',
#  '13-Jun-1987',
#  '14-Jun-2012',
#  '16-Sep-2017',
#  '1957',
#  '23-Jun-1955',
#  '28-Apr-1996',
#  '28-Nov-1993',
#  '29-Aug-1981',
#  '8-Sep-1966',
#  'Aug-1963',
#  'Before 1934',
#  'Nov-1942',
#  'Nov-1970',
#  nan}

# %%
set(df_attacks['Case Number'].sample(n=50)) #Case Number = Date
# Out:
# {'0',
#  '1862.00.00.b',
#  '1885.07.26.c',
#  '1887.01.20',
#  '1901.06.24',
#  '1960.00.00.b',
#  '1961.09.26',
#  '1982.03.07',
#  '2015.07.26.a',
#  nan}

# %%
list(df_attacks.columns)
# Out:
# ['Case Number',
#  'Date',
#  'Year',
#  'Type',
#  'Country',
#  'Area',
#  'Location',
#  'Activity',
#  'Name',
#  'Sex ',
#  'Age',
#  'Injury',
#  'Fatal (Y/N)',
#  'Time',
#  'Species ',
#  'Investigator or Source',
#  'pdf',
#  'href formula',
#  'href',
#  'Case Number.1',
#  'Case Number.2',
#  'original order',
#  'Unnamed: 22',
#  'Unnamed: 23']

# %%
df_attacks = df_attacks.drop(['Date', 'Year', 'pdf',
 'href formula',
 'href',
 'Case Number.1',
 'Case Number.2',
 'original order',
 'Unnamed: 22',
 'Unnamed: 23'],axis=1) #I'll use Case Number as Date

# %%
df_attacks.head(3)
# Out:
#   Case Number        Type Country        Area                        Location  \
# 0  2018.06.25     Boating     USA  California     Oceanside, San Diego County
# 1  2018.06.18  Unprovoked     USA     Georgia  St. Simon Island, Glynn County
# 2  2018.06.09     Invalid     USA      Hawaii                    Habush, Oahu
#
#    Activity             Name Sex  Age  \
# 0  Paddling      Julie Wolfe    F  57
# 1  Standing  Adyson McNeely     F  11
# 2   Surfing      John Denges    M  48
#
#                                               Injury Fatal (Y/N)  \
# 0  No injury to occupant, outrigger canoe and pad...           N
# 1                         Minor injury to left thigh           N
# 2       Injury to left lower leg from surfboard skeg           N
#
#             Time     Species           Investigator or Source
# 0          18h00  White shark                R. Collier, GSAF
# 1  14h00  -15h00          NaN  K.McMurray, TrackingSharks.com
# 2          07h45          NaN  K.McMurray, TrackingSharks.com

# %%
df_attacks = df_attacks.replace({'0': np.nan, 0: np.nan})
#drop all NaN rows

# %%
df_attacks.dropna(how='all', inplace=True)

# %%
df_attacks.shape #new dataframe size
# Out:
# (6303, 14)

# %%
#Derivate dates from 'Case Number' column

# %%
df_attacks['Full_Date'] = df_attacks["Case Number"].str.extract(r'(\d{4}.\d{2}.\d{2})')
#extracted the useful characters from the string

# %%
df_attacks[['year','month', 'day']] =  df_attacks.Full_Date.str.split(".", expand=True)
#created 3 new columns to have a separated date

# %%
df_attacks.sample(3)
# Out:
#        Case Number        Type      Country        Area  \
# 266   2016.06.05.b  Unprovoked          USA     Florida
# 2003    2000.09.29  Unprovoked          USA  California
# 4334    1954.07.15  Unprovoked  THE BALKANS    Slovenia
#
#                                         Location              Activity  \
# 266                Flagler Beach, Flagler County              Swimming
# 2003  Mavericks, Half Moon Bay, San Mateo County  Sitting on surfboard
# 4334                Between Punta Grossa & Koper              Swimming
#
#                      Name Sex   Age      Injury Fatal (Y/N)   Time  \
# 266                  male    M   64  Leg bitten           N  08h30
# 2003           Peck Euwer    M  NaN   No injury           N  09h00
# 4334  a Hungarian refugee    M  NaN       FATAL           Y  21h00
#
#                       Species   \
# 266                        NaN
# 2003  White shark, 4.3 m [14']
# 4334                       NaN
#
#                                  Investigator or Source   Full_Date  year  \
# 266                Daytona Beach News-Journal, 6/5/2016  2016.06.05  2016
# 2003  P. Euwer, Ocean.com; D.W. Cole & M. DesJardins...  2000.09.29  2000
# 4334  R. Rocconi & C. Moore, GSAF            V.M. Co...  1954.07.15  1954
#
#      month day
# 266     06  05
# 2003    09  29
# 4334    07  15

# %%
df_attacks.year = df_attacks.year.str.extract(r'(\d{4})')
#Clean years with extra information

# %%
df_attacks.year.fillna(0, inplace=True) #nans to zero

# %%
df_attacks.year = df_attacks.year.astype(dtype='int') #Year to int

# %%
df_attacks.year.unique() #min 1543
# Out:
# array([2018, 2017, 2016, 2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008,
#        2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000, 1999, 1998, 1997,
#        1996, 1995, 1984, 1994, 1993, 1992, 1991, 1990, 1989, 1988, 1987,
#        1986, 1985, 1983, 1982, 1981, 1980, 1979, 1978, 1977, 1976, 1975,
#        1974, 1973, 1972, 1971, 1970, 1969, 1968, 1967, 1966, 1965, 1964,
#        1963, 1962, 1961, 1960, 1959, 1958, 1957, 1956, 1955, 1954, 1953,
#        1952, 1951, 1851, 1950, 1949, 1948, 1947, 1946, 1945, 1944, 1943,
#        1942, 1941, 1940, 1939, 1938, 1937, 1936, 1935, 1934, 1933, 1932,
#        1931, 1930, 1929, 1928, 1927, 1926, 1925, 1924, 1923, 1922, 1921,
#        1920, 1919, 1900, 1918, 1917, 1916, 1915, 1914, 1913, 1912, 1911,
#        1910, 1909, 1908, 1907, 1906, 1905,    0, 1904, 1903, 1902, 1901,
#        1899, 1898, 1897, 1896, 1895, 1894, 1893, 1892, 1891, 1890, 1889,
#        1888, 1887, 1886, 1885, 1884, 1883, 1882, 1881, 1880, 1879, 1878,
#        1877, 1876, 1875, 1874, 1873, 1872, 1871, 1870, 1869, 1868, 1867,
#        1866, 1865, 1864, 1863, 1862, 1861, 1860, 1859, 1858, 1857, 1856,
#        1855, 1853, 1852, 1850, 1849, 1848, 1847, 1846, 1845, 1844, 1842,
#        1841, 1840, 1839, 1837, 1836, 1835, 1834, 1832, 1831, 1830, 1829,
#        1828, 1827, 1826, 1825, 1823, 1822, 1819, 1818, 1817, 1816, 1815,
#        1812, 1811, 1810, 1808, 1807, 1806, 1805, 1804, 1803, 1802, 1801,
#        1800, 1797, 1792, 1791, 1788, 1787, 1786, 1785, 1784, 1783, 1780,
#        1779, 1776, 1771, 1767, 1764, 1758, 1753, 1751, 1749, 1755, 1748,
#        1742, 1738, 1733, 1723, 1721, 1703, 1700, 1642, 1638, 1637, 1617,
#        1595, 1580, 1555, 1554, 1543,  500,   77,    5])

# %%
#Transform month to numbers as we did with Year:
df_attacks.month = df_attacks.month.str.extract(r'(\d{2})')
df_attacks.month.fillna(0, inplace=True)
df_attacks.month = df_attacks.month.astype(dtype='int')
df_attacks.month.unique()
# Out:
# array([ 6,  5,  4,  3,  2,  1, 12, 11, 10,  9,  8,  7,  0, 30, 29])

# %%
#Transform day to numbers
df_attacks.day = df_attacks.day.str.extract(r'(\d{2})')
df_attacks.day.fillna(0, inplace=True)
df_attacks.day = df_attacks.day.astype(dtype='int')
df_attacks.day.unique()
# Out:
# array([25, 18,  9,  8,  4,  3, 27, 26, 24, 21, 13,  0, 12, 30, 28, 23, 22,
#        19, 15, 14, 10,  5, 31, 17, 11,  1, 20, 16,  6,  2, 29,  7, 38])

# %%
df_attacks.year = np.where(df_attacks.year < 1543, 0, df_attacks.year)

# %%
df_attacks.month = np.where(df_attacks.month > 12, 0, df_attacks.month)

# %%
df_attacks.day = np.where(df_attacks.day > 31, 0, df_attacks.day)

# %%
df_attacks.year.unique() #final list
# Out:
# array([2018, 2017, 2016, 2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008,
#        2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000, 1999, 1998, 1997,
#        1996, 1995, 1984, 1994, 1993, 1992, 1991, 1990, 1989, 1988, 1987,
#        1986, 1985, 1983, 1982, 1981, 1980, 1979, 1978, 1977, 1976, 1975,
#        1974, 1973, 1972, 1971, 1970, 1969, 1968, 1967, 1966, 1965, 1964,
#        1963, 1962, 1961, 1960, 1959, 1958, 1957, 1956, 1955, 1954, 1953,
#        1952, 1951, 1851, 1950, 1949, 1948, 1947, 1946, 1945, 1944, 1943,
#        1942, 1941, 1940, 1939, 1938, 1937, 1936, 1935, 1934, 1933, 1932,
#        1931, 1930, 1929, 1928, 1927, 1926, 1925, 1924, 1923, 1922, 1921,
#        1920, 1919, 1900, 1918, 1917, 1916, 1915, 1914, 1913, 1912, 1911,
#        1910, 1909, 1908, 1907, 1906, 1905,    0, 1904, 1903, 1902, 1901,
#        1899, 1898, 1897, 1896, 1895, 1894, 1893, 1892, 1891, 1890, 1889,
#        1888, 1887, 1886, 1885, 1884, 1883, 1882, 1881, 1880, 1879, 1878,
#        1877, 1876, 1875, 1874, 1873, 1872, 1871, 1870, 1869, 1868, 1867,
#        1866, 1865, 1864, 1863, 1862, 1861, 1860, 1859, 1858, 1857, 1856,
#        1855, 1853, 1852, 1850, 1849, 1848, 1847, 1846, 1845, 1844, 1842,
#        1841, 1840, 1839, 1837, 1836, 1835, 1834, 1832, 1831, 1830, 1829,
#        1828, 1827, 1826, 1825, 1823, 1822, 1819, 1818, 1817, 1816, 1815,
#        1812, 1811, 1810, 1808, 1807, 1806, 1805, 1804, 1803, 1802, 1801,
#        1800, 1797, 1792, 1791, 1788, 1787, 1786, 1785, 1784, 1783, 1780,
#        1779, 1776, 1771, 1767, 1764, 1758, 1753, 1751, 1749, 1755, 1748,
#        1742, 1738, 1733, 1723, 1721, 1703, 1700, 1642, 1638, 1637, 1617,
#        1595, 1580, 1555, 1554, 1543])

# %%
df_attacks.month.unique() #final list
# Out:
# array([ 6,  5,  4,  3,  2,  1, 12, 11, 10,  9,  8,  7,  0])

# %%
df_attacks.day.unique() # final list
# Out:
# array([25, 18,  9,  8,  4,  3, 27, 26, 24, 21, 13,  0, 12, 30, 28, 23, 22,
#        19, 15, 14, 10,  5, 31, 17, 11,  1, 20, 16,  6,  2, 29,  7])

# %%
#Create new date column and make it index
#Rearrenge columns order with dates
#Drop Number Case and Full_Date

df_attacks.head(3)
# Out:
#   Case Number        Type Country        Area                        Location  \
# 0  2018.06.25     Boating     USA  California     Oceanside, San Diego County
# 1  2018.06.18  Unprovoked     USA     Georgia  St. Simon Island, Glynn County
# 2  2018.06.09     Invalid     USA      Hawaii                    Habush, Oahu
#
#    Activity             Name Sex  Age  \
# 0  Paddling      Julie Wolfe    F  57
# 1  Standing  Adyson McNeely     F  11
# 2   Surfing      John Denges    M  48
#
#                                               Injury Fatal (Y/N)  \
# 0  No injury to occupant, outrigger canoe and pad...           N
# 1                         Minor injury to left thigh           N
# 2       Injury to left lower leg from surfboard skeg           N
#
#             Time     Species           Investigator or Source   Full_Date  \
# 0          18h00  White shark                R. Collier, GSAF  2018.06.25
# 1  14h00  -15h00          NaN  K.McMurray, TrackingSharks.com  2018.06.18
# 2          07h45          NaN  K.McMurray, TrackingSharks.com  2018.06.09
#
#    year  month  day
# 0  2018      6   25
# 1  2018      6   18
# 2  2018      6    9

# %%
df_attacks['date'] = pd.to_datetime(df_attacks[['year', 'month', 'day']],errors='coerce')

# %%
df_attacks.head(3)
# Out:
#   Case Number        Type Country        Area                        Location  \
# 0  2018.06.25     Boating     USA  California     Oceanside, San Diego County
# 1  2018.06.18  Unprovoked     USA     Georgia  St. Simon Island, Glynn County
# 2  2018.06.09     Invalid     USA      Hawaii                    Habush, Oahu
#
#    Activity             Name Sex  Age  \
# 0  Paddling      Julie Wolfe    F  57
# 1  Standing  Adyson McNeely     F  11
# 2   Surfing      John Denges    M  48
#
#                                               Injury Fatal (Y/N)  \
# 0  No injury to occupant, outrigger canoe and pad...           N
# 1                         Minor injury to left thigh           N
# 2       Injury to left lower leg from surfboard skeg           N
#
#             Time     Species           Investigator or Source   Full_Date  \
# 0          18h00  White shark                R. Collier, GSAF  2018.06.25
# 1  14h00  -15h00          NaN  K.McMurray, TrackingSharks.com  2018.06.18
# 2          07h45          NaN  K.McMurray, TrackingSharks.com  2018.06.09
#
#    year  month  day       date
# 0  2018      6   25 2018-06-25
# 1  2018      6   18 2018-06-18
# 2  2018      6    9 2018-06-09

# %%
#continue droping useless columns:
df_attacks = df_attacks.drop(['Case Number', 'Full_Date'], axis=1)

# %%
#create week_number column for further analysis:
df_attacks['week_number'] = df_attacks['date'].dt.strftime('%U')

# %%
df_attacks.head(3)
# Out:
#          Type Country        Area                        Location  Activity  \
# 0     Boating     USA  California     Oceanside, San Diego County  Paddling
# 1  Unprovoked     USA     Georgia  St. Simon Island, Glynn County  Standing
# 2     Invalid     USA      Hawaii                    Habush, Oahu   Surfing
#
#               Name Sex  Age  \
# 0      Julie Wolfe    F  57
# 1  Adyson McNeely     F  11
# 2      John Denges    M  48
#
#                                               Injury Fatal (Y/N)  \
# 0  No injury to occupant, outrigger canoe and pad...           N
# 1                         Minor injury to left thigh           N
# 2       Injury to left lower leg from surfboard skeg           N
#
#             Time     Species           Investigator or Source  year  month  \
# 0          18h00  White shark                R. Collier, GSAF  2018      6
# 1  14h00  -15h00          NaN  K.McMurray, TrackingSharks.com  2018      6
# 2          07h45          NaN  K.McMurray, TrackingSharks.com  2018      6
#
#    day       date week_number
# 0   25 2018-06-25          25
# 1   18 2018-06-18          24
# 2    9 2018-06-09          22

# %%
list(df_attacks.Time.unique()) #will also try to clean time column to analyze the 'hours'
# Out:
# ['18h00',
#  '14h00  -15h00',
#  '07h45',
#  nan,
#  'Late afternoon',
#  '17h00',
#  '14h00',
#  'Morning',
#  '15h00',
#  '08h15',
#  '11h00',
#  '10h30',
#  '10h40',
#  '16h50',
#  '07h00',
#  '09h30',
#  'Afternoon',
#  '21h50',
#  '09h40',
#  '08h00',
#  '17h35',
#  '15h30',
#  '07h30',
#  '19h00, Dusk',
#  'Night',
#  '16h00',
#  '15h01',
#  '12h00',
#  '13h45',
#  '23h30',
#  '09h00',
#  '14h30',
#  '18h30',
#  '12h30',
#  '16h30',
#  '18h45',
#  '06h00',
#  '10h00',
#  '10h44',
#  '13h19',
#  'Midday',
#  '13h30',
#  '10h45',
#  '11h20',
#  '11h45',
#  '19h30',
#  '08h30',
#  '15h45',
#  'Shortly before 12h00',
#  '17h34',
#  '17h10',
#  '11h15',
#  '08h50',
#  '17h45',
#  '13h00',
#  '10h20',
#  '13h20',
#  '02h00',
#  '09h50',
#  '11h30',
#  '17h30',
#  '9h00',
#  '10h43',
#  'After noon',
#  '15h15',
#  '15h40',
#  '19h05',
#  '1300',
#  '14h30 / 15h30',
#  '22h00',
#  '16h20',
#  '14h34',
#  '15h25',
#  '14h55',
#  '17h46',
#  'Morning ',
#  '15h49',
#  '19h00',
#  'Midnight',
#  '09h30 / 10h00',
#  '10h15',
#  '18h15',
#  '04h00',
#  '14h50',
#  '13h50',
#  '19h20',
#  '10h25',
#  '10h45-11h15',
#  '16h45',
#  '15h52',
#  '06h15',
#  '14h40',
#  '19h45',
#  '10h10',
#  '08h45',
#  'Evening',
#  '12h10',
#  '18h05',
#  '11h41',
#  '12h25',
#  '17h51',
#  '16h12',
#  '12h45',
#  '10h50',
#  '14h15',
#  '09h45',
#  '06h45',
#  '05h00',
#  '03h30',
#  'Sometime between 06h00 & 08hoo',
#  '06h30',
#  '17h20',
#  '20h00',
#  '16h40',
#  '16h18',
#  '11h10',
#  'Early afternoon',
#  '17h50',
#  '07h00 - 08h00',
#  '18h15-18h30',
#  '17h01',
#  '09h57',
#  '08h20',
#  '17h58',
#  '20h30',
#  '15h19',
#  '10h55',
#  '15h55',
#  '23h00',
#  '12h40',
#  '13h55',
#  '16h05',
#  '14h10',
#  '15h20',
#  '12h50',
#  '14h45',
#  '13h40',
#  '13h24',
#  '09h00 - 09h30',
#  '0830',
#  '11h40',
#  '08h10',
#  '15h56',
#  '14h20',
#  'Just before noon',
#  '07h56',
#  '1600',
#  '17h17',
#  '16h35',
#  '09h05',
#  '07h15',
#  '07h20',
#  '19h28',
#  '12h38',
#  '05h50',
#  '15h50',
#  '11h05',
#  'Early morning',
#  'Dawn',
#  '05h45',
#  '13h25',
#  '12h20',
#  '13h26',
#  '09h11',
#  '12h15',
#  '13h15',
#  '18h20',
#  '15h35',
#  'AM',
#  '13h51',
#  'A.M.',
#  '08h05',
#  '19h15',
#  '10h35',
#  '15h44',
#  'Dusk',
#  '21h00',
#  'Lunchtime',
#  '15j45',
#  '09h35',
#  '10h27',
#  '10h16',
#  '0500',
#  'Before 07h00',
#  '09h20',
#  '10h00 -- 11h00',
#  '12h05',
#  '14h21',
#  '18h50',
#  '15h53',
#  '"Just before 11h00"',
#  '11h115',
#  '13h42',
#  '20h15',
#  '12h39',
#  '07h05',
#  'Sunset',
#  '  ',
#  '13h05',
#  '11h50',
#  '"Evening"',
#  'Just before sundown',
#  '17h55',
#  '22h30',
#  '17h15',
#  '16h10',
#  '11h30 ',
#  '06h10',
#  '16h15',
#  'Between 05h00 and 08h00',
#  '07h08',
#  '17h00 or 17h40',
#  '03h00',
#  '>08h00',
#  '--',
#  '12h02',
#  '12h55',
#  '16h14',
#  '17h11',
#  '00h30',
#  '14h37',
#  '10h07',
#  '13h53',
#  '11h55',
#  '13h23',
#  'Just after 12h00',
#  '02h30',
#  '08h40',
#  '11h56',
#  '14h35',
#  ' ',
#  'Early Morning',
#  '07h50',
#  'Shortly after midnight',
#  '14h25',
#  '13h345',
#  '\xa0 ',
#  '06h47',
#  '09h00 -10h00',
#  '20h45 (Sunset)',
#  'Late morning',
#  'P.M.',
#  '18h40',
#  '13h14',
#  '13h06',
#  'Shortly before 13h00',
#  '12h34',
#  '11h53',
#  '8:04 pm',
#  '12h46',
#  '12h48',
#  '17h42',
#  '12h35',
#  'Possibly same incident as 2000.08.21',
#  'After Dusk',
#  '11h57',
#  'Noon',
#  '17h40',
#  '11h25',
#  '18h25',
#  '10h28',
#  '09h15',
#  '14h16',
#  '09h55',
#  '2 hours after Opperman',
#  '15h05',
#  '09h30 ',
#  'Mid afternoon',
#  'Mid morning',
#  '11h48',
#  '11h00 / 11h30',
#  '07h19',
#  '13h37',
#  '11h06',
#  '"Night"',
#  '18h30?',
#  '11h58',
#  '11h51',
#  '18h12',
#  '07h10',
#  '07h40',
#  '12h33',
#  '30 minutes after 1992.07.08.a',
#  '>06h45',
#  '15h06',
#  '12h54',
#  'Between 06h00 & 07h20',
#  '16h55',
#  '05h40',
#  '<07h30',
#  '21h30',
#  '17h00 Sunset',
#  'Nightfall',
#  'X',
#  '08h57',
#  '18h30 (Sunset)',
#  '06j00',
#  '08h35',
#  '10h22',
#  '02h45',
#  'Prior to 10h37',
#  'Daybreak',
#  '18h10',
#  '>12h00',
#  'Mid-morning',
#  '08h55',
#  '16h30 or 18h00',
#  'Just before dawn',
#  ' 14h00',
#  'Daytime',
#  '06h50',
#  '01h00',
#  'Dark',
#  '10h00 / 11h00',
#  '"After lunch"',
#  '07h32',
#  '15h00 or 15h45',
#  '>17h00',
#  '19h00 / 20h00',
#  '12h45 / 13h45',
#  '14h00 - 15h00',
#  'night',
#  '03h45 - 04h00',
#  '13h10',
#  '09h30 / 15h30',
#  '08h00 / 09h30',
#  '19h35',
#  '12h00 to 14h00',
#  '13h35',
#  'Late night',
#  '01h32',
#  '10h30 or 13h30',
#  '16h23',
#  '15h00j',
#  'Midday.',
#  '"After dark"',
#  '10h00 or 14h00',
#  '19h10',
#  '16h25',
#  '2 hrs before sunset',
#  '18h15 to 21h30',
#  '1500',
#  '"shortly before dusk"',
#  '>17h30',
#  '>14h30',
#  'Between 11h00 & 12h00',
#  'After 04h00',
#  '11h01 -time of ship sinking',
#  'Ship aban-doned at 03h10',
#  '19h55',
#  'After dusk',
#  'FATAL  (Wire netting installed at local beaches after this incident.)',
#  '01h30',
#  'After midnight',
#  'Late afternon',
#  '05h30',
#  '08h58',
#  '"Early evening"',
#  'Late Afternoon',
#  '   ',
#  'Before daybreak',
#  'dusk',
#  'Before 10h30',
#  '06h00 -- 07h00',
#  '01h50',
#  '17h00-18h00',
#  '19h00-20h00']

# %%
df_attacks['hour'] = df_attacks.Time.str.extract(r'(\d{2})')
df_attacks.hour = df_attacks.hour.astype(dtype='float') #left as float as zero is an hour
df_attacks.hour.unique()
# Out:
# array([18., 14.,  7., nan, 17., 15.,  8., 11., 10., 16.,  9., 21., 19.,
#        12., 13., 23.,  6.,  2.,  0., 22.,  4.,  5.,  3., 20., 30.,  1.])

# %%
df_attacks.sample(3)
# Out:
#               Type        Country                                  Area  \
# 4373  Sea Disaster  PACIFIC OCEAN  330 to 350 miles east of Wake Island
# 2860    Unprovoked   SOUTH AFRICA                 Western Cape Province
# 5730       Boating      AUSTRALIA                              Victoria
#
#             Location                                           Activity  \
# 4373             NaN  Royal Hawaiian skymaster DC-6B aircraft went d...
# 2860      Struisbaai                                           Swimming
# 5730  Port Melbourne                                            Fishing
#
#               Name Sex   Age                                    Injury  \
# 4373           NaN  NaN  NaN      Recuers fought sharks for the bodies
# 2860  Marius Botha    M   15      Right knee, calf and ankle lacerated
# 5730         2 men  NaN  NaN  No injury to occupants, shark holed boat
#
#      Fatal (Y/N)     Time           Species   \
# 4373           N      NaN                NaN
# 2860           N    18h30  Raggedtooth shark
# 5730           N  Evening                NaN
#
#                                Investigator or Source  year  month  day  \
# 4373  Guam Daily News, 7/16/195; V.M. Coppleson, p.21  1953      7   11
# 2860                        M. Botha, M. Levine, GSAF  1985      1   27
# 5730                        Taranaki Herald, 7/9/1888  1888      6   24
#
#            date week_number  hour
# 4373 1953-07-11          27   NaN
# 2860 1985-01-27          04  18.0
# 5730 1888-06-24          26   NaN

# %%
#### DATES ARE READY###
#now clean categories#

# %%
#Type cleaning:
set(df_attacks.Type)
# Out:
# {'Boat',
#  'Boating',
#  'Boatomg',
#  'Invalid',
#  'Provoked',
#  'Questionable',
#  'Sea Disaster',
#  'Unprovoked',
#  nan}

# %%
df_attacks.Type = df_attacks.Type.replace({'Boat': 'Boating', 'Boatomg': 'Boating', 'Invalid': 'Unknown', 'Questionable': 'Unknown', 'Sea Disaster': 'Shipwreck'})
df_attacks.Type.fillna('Unknown', inplace=True)
set(df_attacks.Type)
# Out:
# {'Boating', 'Provoked', 'Shipwreck', 'Unknown', 'Unprovoked'}

# %%
#Country cleaning:
set(df_attacks.Country)
# Out:
# {' PHILIPPINES',
#  ' TONGA',
#  'ADMIRALTY ISLANDS',
#  'AFRICA',
#  'ALGERIA',
#  'AMERICAN SAMOA',
#  'ANDAMAN / NICOBAR ISLANDAS',
#  'ANDAMAN ISLANDS',
#  'ANGOLA',
#  'ANTIGUA',
#  'ARGENTINA',
#  'ARUBA',
#  'ASIA?',
#  'ATLANTIC OCEAN',
#  'AUSTRALIA',
#  'AZORES',
#  'BAHAMAS',
#  'BAHREIN',
#  'BANGLADESH',
#  'BARBADOS',
#  'BAY OF BENGAL',
#  'BELIZE',
#  'BERMUDA',
#  'BRAZIL',
#  'BRITISH ISLES',
#  'BRITISH NEW GUINEA',
#  'BRITISH VIRGIN ISLANDS',
#  'BRITISH WEST INDIES',
#  'BURMA',
#  'Between PORTUGAL & INDIA',
#  'CANADA',
#  'CAPE VERDE',
#  'CARIBBEAN SEA',
#  'CAYMAN ISLANDS',
#  'CENTRAL PACIFIC',
#  'CEYLON',
#  'CEYLON (SRI LANKA)',
#  'CHILE',
#  'CHINA',
#  'COLUMBIA',
#  'COMOROS',
#  'COOK ISLANDS',
#  'COSTA RICA',
#  'CRETE',
#  'CROATIA',
#  'CUBA',
#  'CURACAO',
#  'CYPRUS',
#  'Coast of AFRICA',
#  'DIEGO GARCIA',
#  'DJIBOUTI',
#  'DOMINICAN REPUBLIC',
#  'ECUADOR',
#  'EGYPT',
#  'EGYPT ',
#  'EGYPT / ISRAEL',
#  'EL SALVADOR',
#  'ENGLAND',
#  'EQUATORIAL GUINEA / CAMEROON',
#  'FALKLAND ISLANDS',
#  'FEDERATED STATES OF MICRONESIA',
#  'FIJI',
#  'FRANCE',
#  'FRENCH POLYNESIA',
#  'Fiji',
#  'GABON',
#  'GEORGIA',
#  'GHANA',
#  'GRAND CAYMAN',
#  'GREECE',
#  'GREENLAND',
#  'GRENADA',
#  'GUAM',
#  'GUATEMALA',
#  'GUINEA',
#  'GULF OF ADEN',
#  'GUYANA',
#  'HAITI',
#  'HONDURAS',
#  'HONG KONG',
#  'ICELAND',
#  'INDIA',
#  'INDIAN OCEAN',
#  'INDIAN OCEAN?',
#  'INDONESIA',
#  'IRAN',
#  'IRAN / IRAQ',
#  'IRAQ',
#  'IRELAND',
#  'ISRAEL',
#  'ITALY',
#  'ITALY / CROATIA',
#  'JAMAICA',
#  'JAPAN',
#  'JAVA',
#  'JOHNSTON ISLAND',
#  'KENYA',
#  'KIRIBATI',
#  'KOREA',
#  'KUWAIT',
#  'LEBANON',
#  'LIBERIA',
#  'LIBYA',
#  'MADAGASCAR',
#  'MALAYSIA',
#  'MALDIVE ISLANDS',
#  'MALDIVES',
#  'MALTA',
#  'MARSHALL ISLANDS',
#  'MARTINIQUE',
#  'MAURITIUS',
#  'MAYOTTE',
#  'MEDITERRANEAN SEA',
#  'MEXICO',
#  'MEXICO ',
#  'MICRONESIA',
#  'MID ATLANTIC OCEAN',
#  'MID-PACIFC OCEAN',
#  'MONACO',
#  'MONTENEGRO',
#  'MOZAMBIQUE',
#  'NAMIBIA',
#  'NETHERLANDS ANTILLES',
#  'NEVIS',
#  'NEW BRITAIN',
#  'NEW CALEDONIA',
#  'NEW GUINEA',
#  'NEW ZEALAND',
#  'NICARAGUA',
#  'NICARAGUA ',
#  'NIGERIA',
#  'NORTH ATLANTIC OCEAN',
#  'NORTH ATLANTIC OCEAN ',
#  'NORTH PACIFIC OCEAN',
#  'NORTH SEA',
#  'NORTHERN ARABIAN SEA',
#  'NORTHERN MARIANA ISLANDS',
#  'NORWAY',
#  'OCEAN',
#  'OKINAWA',
#  'PACIFIC OCEAN',
#  'PACIFIC OCEAN ',
#  'PALAU',
#  'PALESTINIAN TERRITORIES',
#  'PANAMA',
#  'PAPUA NEW GUINEA',
#  'PARAGUAY',
#  'PERSIAN GULF',
#  'PERU',
#  'PHILIPPINES',
#  'PORTUGAL',
#  'PUERTO RICO',
#  'RED SEA',
#  'RED SEA / INDIAN OCEAN',
#  'RED SEA?',
#  'REUNION',
#  'REUNION ISLAND',
#  'ROATAN',
#  'RUSSIA',
#  'SAMOA',
#  'SAN DOMINGO',
#  'SAUDI ARABIA',
#  'SCOTLAND',
#  'SENEGAL',
#  'SEYCHELLES',
#  'SIERRA LEONE',
#  'SINGAPORE',
#  'SLOVENIA',
#  'SOLOMON ISLANDS',
#  'SOLOMON ISLANDS / VANUATU',
#  'SOMALIA',
#  'SOUTH AFRICA',
#  'SOUTH ATLANTIC OCEAN',
#  'SOUTH CHINA SEA',
#  'SOUTH KOREA',
#  'SOUTH PACIFIC OCEAN',
#  'SOUTHWEST PACIFIC OCEAN',
#  'SPAIN',
#  'SRI LANKA',
#  'ST HELENA, British overseas territory',
#  'ST. MAARTIN',
#  'ST. MARTIN',
#  'SUDAN',
#  'SUDAN?',
#  'SWEDEN',
#  'SYRIA',
#  'Seychelles',
#  'Sierra Leone',
#  'TAIWAN',
#  'TANZANIA',
#  'TASMAN SEA',
#  'THAILAND',
#  'THE BALKANS',
#  'TOBAGO',
#  'TONGA',
#  'TRINIDAD & TOBAGO',
#  'TUNISIA',
#  'TURKEY',
#  'TURKS & CAICOS',
#  'TUVALU',
#  'UNITED ARAB EMIRATES',
#  'UNITED ARAB EMIRATES (UAE)',
#  'UNITED KINGDOM',
#  'URUGUAY',
#  'USA',
#  'VANUATU',
#  'VENEZUELA',
#  'VIETNAM',
#  'WEST INDIES',
#  'WESTERN SAMOA',
#  'YEMEN',
#  'YEMEN ',
#  nan}

# %%
#A lot of homologation!!!
df_attacks.Country = df_attacks.Country.replace({'ANDAMAN / NICOBAR ISLANDAS': 'ANDAMAN ISLANDS', 'ASIA?': 'ASIA',
                                                'Between PORTUGAL & INDIA': 'PORTUGAL', 'CEYLON (SRI LANKA)': 'CEYLON',
                                                 ' TONGA': 'TONGA',
                                                'Coast of AFRICA': 'AFRICA', 
                                                'DIEGO GARCIA': 'Unknown',
                                                'EGYPT ': 'EGYPT',
                                                'EGYPT / ISRAEL': 'EGYPT',
                                                'EQUATORIAL GUINEA / CAMEROON': 'CAMEROON',
                                                'GRAND CAYMAN':'CAYMAN ISLANDS',
                                                'IRAN / IRAQ': 'IRAN',
                                                'ITALY / CROATIA': 'ITALY',
                                                'MALDIVE ISLANDS': 'MALDIVES',
                                                'MEXICO ': 'MEXICO',
                                                'MID ATLANTIC OCEAN': 'ATLANTIC OCEAN',
                                                'MID-PACIFC OCEAN': 'PACIFIC OCEAN',
                                                'NICARAGUA ': 'NICARAGUA',
                                                'NORTH ATLANTIC OCEAN': 'ATLANTIC OCEAN',
                                                'NORTH ATLANTIC OCEAN ': 'ATLANTIC OCEAN',
                                                'NORTH PACIFIC OCEAN': 'PACIFIC OCEAN',
                                                'NORTHERN ARABIAN SEA': 'ARABIAN SEA',
                                                'NORTHERN MARIANA ISLANDS': 'MARIANA ISLANDS',
                                                'OCEAN': 'UNKNOWN',
                                                'PACIFIC OCEAN ': 'PACIFIC OCEAN',
                                                'PALESTINIAN TERRITORIES': 'MEDITERRANEAN SEA',
                                                'RED SEA / INDIAN OCEAN': 'RED SEA',
                                                'RED SEA?': 'RED SEA',
                                                'REUNION ISLAND': 'REUNION',
                                                'SAN DOMINGO': 'DOMINICAN REPUBLIC',
                                                'SOLOMON ISLANDS / VANUATU': 'SOLOMON ISLANDS',
                                                'SOUTH ATLANTIC OCEAN': 'ATLANTIC OCEAN',
                                                'SOUTH CHINA SEA': 'CHINA',
                                                'SOUTH PACIFIC OCEAN': 'PACIFIC OCEAN',
                                                'SOUTHWEST PACIFIC OCEAN': 'PACIFIC OCEAN',
                                                'ST. HELENA, British overseas territory': 'ST HELENA',
                                                'ST. MAARTIN': 'ST. MARTIN',
                                                'SUDAN?':'SUDAN',
                                                'THE BALKANS': 'ADRIATIC SEA',
                                                'TOBAGO': 'TRINIDAD & TOBAGO',
                                                'UNITED ARAB EMIRATES (UAE)': 'UNITED ARAB EMIRATES',
                                                'YEMEN ': 'YEMEN',
                                                'INDIAN OCEAN': 'INDIA',
                                                'INDIAN OCEAN?': 'INDIA',
                                                ' PHILIPPINES': 'PHILIPPINES',
                                                'ST HELENA, British overseas territory':'ST. HELENA',
                                                'Usa':'United States',
                                                'USA':'United States'})

# %%
df_attacks.Country.fillna('Unknown', inplace=True)
df_attacks.Country = df_attacks.Country.astype(dtype='str')
df_attacks.Country = df_attacks.Country.str.title()
set(df_attacks.Country) #Country category is still cluttered but clean enough to work with top countries by attack.
# Out:
# {'Admiralty Islands',
#  'Adriatic Sea',
#  'Africa',
#  'Algeria',
#  'American Samoa',
#  'Andaman Islands',
#  'Angola',
#  'Antigua',
#  'Arabian Sea',
#  'Argentina',
#  'Aruba',
#  'Asia',
#  'Atlantic Ocean',
#  'Australia',
#  'Azores',
#  'Bahamas',
#  'Bahrein',
#  'Bangladesh',
#  'Barbados',
#  'Bay Of Bengal',
#  'Belize',
#  'Bermuda',
#  'Brazil',
#  'British Isles',
#  'British New Guinea',
#  'British Virgin Islands',
#  'British West Indies',
#  'Burma',
#  'Cameroon',
#  'Canada',
#  'Cape Verde',
#  'Caribbean Sea',
#  'Cayman Islands',
#  'Central Pacific',
#  'Ceylon',
#  'Chile',
#  'China',
#  'Columbia',
#  'Comoros',
#  'Cook Islands',
#  'Costa Rica',
#  'Crete',
#  'Croatia',
#  'Cuba',
#  'Curacao',
#  'Cyprus',
#  'Djibouti',
#  'Dominican Republic',
#  'Ecuador',
#  'Egypt',
#  'El Salvador',
#  'England',
#  'Falkland Islands',
#  'Federated States Of Micronesia',
#  'Fiji',
#  'France',
#  'French Polynesia',
#  'Gabon',
#  'Georgia',
#  'Ghana',
#  'Greece',
#  'Greenland',
#  'Grenada',
#  'Guam',
#  'Guatemala',
#  'Guinea',
#  'Gulf Of Aden',
#  'Guyana',
#  'Haiti',
#  'Honduras',
#  'Hong Kong',
#  'Iceland',
#  'India',
#  'Indonesia',
#  'Iran',
#  'Iraq',
#  'Ireland',
#  'Israel',
#  'Italy',
#  'Jamaica',
#  'Japan',
#  'Java',
#  'Johnston Island',
#  'Kenya',
#  'Kiribati',
#  'Korea',
#  'Kuwait',
#  'Lebanon',
#  'Liberia',
#  'Libya',
#  'Madagascar',
#  'Malaysia',
#  'Maldives',
#  'Malta',
#  'Mariana Islands',
#  'Marshall Islands',
#  'Martinique',
#  'Mauritius',
#  'Mayotte',
#  'Mediterranean Sea',
#  'Mexico',
#  'Micronesia',
#  'Monaco',
#  'Montenegro',
#  'Mozambique',
#  'Namibia',
#  'Netherlands Antilles',
#  'Nevis',
#  'New Britain',
#  'New Caledonia',
#  'New Guinea',
#  'New Zealand',
#  'Nicaragua',
#  'Nigeria',
#  'North Sea',
#  'Norway',
#  'Okinawa',
#  'Pacific Ocean',
#  'Palau',
#  'Panama',
#  'Papua New Guinea',
#  'Paraguay',
#  'Persian Gulf',
#  'Peru',
#  'Philippines',
#  'Portugal',
#  'Puerto Rico',
#  'Red Sea',
#  'Reunion',
#  'Roatan',
#  'Russia',
#  'Samoa',
#  'Saudi Arabia',
#  'Scotland',
#  'Senegal',
#  'Seychelles',
#  'Sierra Leone',
#  'Singapore',
#  'Slovenia',
#  'Solomon Islands',
#  'Somalia',
#  'South Africa',
#  'South Korea',
#  'Spain',
#  'Sri Lanka',
#  'St. Helena',
#  'St. Martin',
#  'Sudan',
#  'Sweden',
#  'Syria',
#  'Taiwan',
#  'Tanzania',
#  'Tasman Sea',
#  'Thailand',
#  'Tonga',
#  'Trinidad & Tobago',
#  'Tunisia',
#  'Turkey',
#  'Turks & Caicos',
#  'Tuvalu',
#  'United Arab Emirates',
#  'United Kingdom',
#  'United States',
#  'Unknown',
#  'Uruguay',
#  'Vanuatu',
#  'Venezuela',
#  'Vietnam',
#  'West Indies',
#  'Western Samoa',
#  'Yemen'}

# %%
#Reduce 'activity' dimensions:
df_attacks.Activity.fillna('Unknown', inplace=True)
df_attacks['activity'] = df_attacks.Activity.str.extract(r'(\w*ing[^\w])')
df_attacks['activity'] = df_attacks.activity.str.extract(r'(\w+)')
df_attacks.activity.fillna('Unknown', inplace=True)
df_attacks.activity = df_attacks.activity.astype(dtype='str')
df_attacks.activity = df_attacks.activity.str.title()
dict(df_attacks['activity'].value_counts())
# Out:
# {'Unknown': 4908,
#  'Swimming': 218,
#  'Fishing': 216,
#  'Diving': 213,
#  'Spearfishing': 73,
#  'Surfing': 50,
#  'Treading': 39,
#  'Floating': 34,
#  'Standing': 32,
#  'Attempting': 32,
#  'Bathing': 23,
#  'Sitting': 20,
#  'Wading': 18,
#  'Playing': 18,
#  'Sinking': 14,
#  'Paddling': 13,
#  'Feeding': 12,
#  'Collecting': 12,
#  'Washing': 11,
#  'During': 9,
#  'Walking': 9,
#  'Kayaking': 9,
#  'Clinging': 8,
#  'Boarding': 7,
#  'Removing': 7,
#  'Rowing': 7,
#  'Skiing': 7,
#  'Lying': 7,
#  'Hunting': 7,
#  'Competing': 6,
#  'Crossing': 6,
#  'Lifesaving': 5,
#  'Splashing': 5,
#  'Snorkeling': 5,
#  'Netting': 5,
#  'Pulling': 5,
#  'Filming': 5,
#  'Cleaning': 5,
#  'Dangling': 5,
#  'Skindiving': 4,
#  'Catching': 4,
#  'Spearing': 4,
#  'Returning': 4,
#  'Freediving': 4,
#  'Riding': 4,
#  'Working': 4,
#  'Escaping': 4,
#  'Being': 4,
#  'Killing': 4,
#  'Tagging': 4,
#  'Dragging': 4,
#  'Taking': 3,
#  'Sailing': 3,
#  'Carrying': 3,
#  'Touching': 3,
#  'Flying': 3,
#  'Launching': 3,
#  'Climbing': 3,
#  'Gathering': 3,
#  'Testing': 3,
#  'Photographing': 3,
#  'Hauling': 3,
#  'Helping': 3,
#  'Holding': 3,
#  'Picking': 3,
#  'Preparing': 3,
#  'Watching': 3,
#  'Finning': 3,
#  'Jumping': 2,
#  'Chumming': 2,
#  'Hoisting': 2,
#  'Teasing': 2,
#  'Towing': 2,
#  'Resting': 2,
#  'Petting': 2,
#  'Conducting': 2,
#  'Shooting': 2,
#  'Burning': 2,
#  'Trailing': 2,
#  'Hanging': 2,
#  'Abandoning': 2,
#  'Landing': 2,
#  'Wearing': 2,
#  'Gaffing': 2,
#  'Windsurfing': 2,
#  'Crouching': 2,
#  'Reading': 2,
#  'Moving': 2,
#  'Foundering': 2,
#  'Boeing': 2,
#  'Retrieving': 2,
#  'Ascending': 1,
#  'Bringing': 1,
#  'Waiting': 1,
#  'Travelling': 1,
#  'Guarding': 1,
#  'Scooping': 1,
#  'Rescuing': 1,
#  'Feeling': 1,
#  'Awaiting': 1,
#  'Fighting': 1,
#  'Dismantling': 1,
#  'Yachting': 1,
#  'Trying': 1,
#  'Reaching': 1,
#  'Harassing': 1,
#  'Coming': 1,
#  'Painting': 1,
#  'Salvaging': 1,
#  'Murdering': 1,
#  'Traveling': 1,
#  'Restraining': 1,
#  'Fleeing': 1,
#  'Loading': 1,
#  'Hooking': 1,
#  'Pursuing': 1,
#  'Footing': 1,
#  'Harpooning': 1,
#  'Examining': 1,
#  'Expecting': 1,
#  'Pearling': 1,
#  'Stuffing': 1,
#  'Deserting': 1,
#  'Involving': 1,
#  'Hiking': 1,
#  'Bending': 1,
#  'Sailboarding': 1,
#  'Thrashing': 1,
#  'Drawing': 1,
#  'Measuring': 1,
#  'Exercising': 1,
#  'Reviving': 1,
#  'Morning': 1,
#  'Inspecting': 1,
#  'Investigating': 1,
#  'Wrangling': 1,
#  'Racing': 1,
#  'Ditching': 1,
#  'Dropping': 1,
#  'Sittting': 1,
#  'Observing': 1,
#  'Scurfing': 1,
#  'Sleeping': 1,
#  'Crabbing': 1,
#  'Leaving': 1,
#  'Defecating': 1,
#  'Chasing': 1,
#  'Cutting': 1,
#  'Longling': 1,
#  'Dynamiting': 1,
#  'Grabbing': 1,
#  'Gigging': 1,
#  'Setting': 1,
#  'Lining': 1,
#  'Checking': 1,
#  'Casting': 1,
#  'Attaching': 1,
#  'Missing': 1,
#  'Seining': 1,
#  'Searching': 1,
#  'Sunbathing': 1,
#  'Throwing': 1,
#  'Kneeling': 1,
#  'Lashing': 1}

# %%
### Clean sex column:

# %%
dict(df_attacks['Sex '].value_counts())
df_attacks['sex'] = df_attacks['Sex '].replace({'M ':'M', 'N':'M', '.':'M', 'lli':'M'})
df_attacks.sex.fillna('Unknown', inplace=True)
df_attacks.sex = df_attacks.sex.astype(dtype='str')

# %%
set(df_attacks.Injury) ### drop Injury type column. Too much dispersion/ambiguous
# Out:
# {nan,
#  'Forearm lacerated',
#  'Lower leg nipped, arm bruised when he landed in boat',
#  '2 people out of +70 survived, one of whom was bitten by sharks',
#  'FATAL, leg severed at knee  ',
#  'Depicts shipwrecked sailors  attacked by a shark/s',
#  'Right thigh punctured',
#  'No injury, left elbow & torso bumped by sharks',
#  'Harpooned shark bit his forehead PROVOKED INCIDENT',
#  'No injury, bow of kayak bitten',
#  'Serious wounds to chest',
#  'Minor injury to finger by netted shark PROVOKED INCIDENT',
#  'Left shoulder & both legs bitten',
#  'FATAL, shark removed large part of his hip',
#  'Right foot abraded & lacerated',
#  'Lacerations to calf, wrist & thumb by hooked shark. PROVOKED INCIDENT',
#  'Puncture wounds to lower arm or hand',
#  'FATAL, "men snatched from rafts by sharks"   ',
#  'Reported as shark attack but probable drowning ',
#  'Survived. questionable incident',
#  'Lower right leg lacerated',
#  'Severe laceration to right knee',
#  'Bitten by hooked shark PROVOKED INCIDENT',
#  'No injury to occupants; shark seized gunwale & tried to overturn boat',
#  'Severe lacerations to lower right leg',
#  'Of her crew of 50, eight perished, including the two injured men',
#  'Fingers & leg lacerated  by hooked shark PROVOKED INCIDENT',
#  'Leg bitten & femur fractured',
#  'Arm & chest injured',
#  'Three small lacerations/ punctures to right foot',
#  'Right foot lacerated',
#  'FATAL      Torso bitten',
#  'Severe lacerations to feet & ankles',
#  'Passengers taken by sharks',
#  'Right arm bitten  PROVOKED INCIDENT',
#  'Bitten on their feet by landed sharks / lacerations only PROVOKED INCIDENTS',
#  'FATAL, remains recovered from 2 sharks',
#  'His feet were bitten by sharks, but he was rescued by a charter boat that arrived on the scene just an hour and 15 minutes after the sharks first appeared, too late to save the lives of Hayes and Beaver',
#  'Lacerations to dorsum of left foot',
#  'Feet severed',
#  'Bitten several times before being rescued after 43 hours in the sea by the freighter Stell Advocate',
#  'Boat bitten by gaffed shark PROVOKED INCIDENT',
#  'Bathing suit torn & "imprints of the shark\'s teeth on his body"',
#  'Major injuries',
#  'No injury, boat towed by harpooned shark, PROVOKED INCIDENT',
#  'Chest bitten',
#  'No injury, shark took his catch, then towed & pushed diver through the water ',
#  '2 lacerations on lower right leg',
#  'No injury, said to have been charged by sharks several times',
#  'Right ankle bitten',
#  'Foot lacerated by hooked shark PROVOKED INCIDENT',
#  'His left leg was severely bitten',
#  'Fingers & hand lacerated',
#  'Minor laceration to leg from a hooked shark PROVOKED INCIDENT',
#  'Left foot bitten & abraded',
#  'Arm & back bitten, heel lacerated',
#  'Bitten on feet, legs, back & abdomen but survived.  Survivors rescued after  7.5 hours in the water',
#  'Leg lacerated',
#  'Shark rammed boat & bit transom',
#  'Bitten by captive sharks PROVOKED INCIDENTS',
#  "FATAL. Of 38 people in the water, 8 were killed by sharks & 1 man's leg was severed",
#  'FATAL, right femoral artery severed, thigh, calf, buttock & left hand bitten  ',
#  '2 semi-circular bites on aft starboard tube of boat',
#  'No injury, shark bit swim fin',
#  'Thigh, lower back and surfboard bitten',
#  'Foot lacerated. Recorded as PROVOKED INCIDENT',
#  'Shoulder bitten. Hana, one of the rescuers, fended shark off with an oar, then shark bit oar in two',
#  'No injury, board dented',
#  'Left arm & thigh bitten',
#  'Stepped on shark PROVOKED INCIDENT',
#  'Bitten on left leg by hooked shark PROVOKED INCIDENT',
#  'Severely lacerated arm PROVOKED INCIDENT',
#  '2 puncture wounds in left leg',
#  'Grabbed shark by the tail & it bit him PROVOKED INCIDENT',
#  'Lacerations to lower left leg after stepping on the shark                 PROVOKED INCIDENT',
#  'Shark leapt into & damaged the dinghy but no injury to occupants',
#  'No injury, paddleski bitten',
#  'Remains of 3 humans recovered from shark, but shark involvement prior to death unconfirmed',
#  'Forearm injured by hooked shark PROVOKED INCIDENT',
#  'Right forearm lacerated',
#  'Left ankle bitten when he stepped on the shark PROVOKED INCIDENT',
#  'FATAL, right leg at hip, left leg and right forearm severed  ',
#  'Buttocks injured by fin or a bump ',
#  'Lacerations and puncture wounds to right foot',
#  'No injury, shark made threat display & impaled itself on spear ',
#  'Lacerations on buttock  &  right foot ',
#  'Abdomen abraded',
#  'Injury required 16 stitches',
#  'No injury, shark made a threat display',
#  'FATAL. Partial remains washed ashore the next day',
#  'A cut on her hand',
#  'FATAL, leg bitten ',
#  '1 man survived & was rescued, sharks took the corpses of the two men that perished',
#  'Foot lacerated when he stepped on the shark  PROVOKED INCIDENT',
#  'Leg bitten, but survived',
#  'FATAL, left thigh & calf bitten  ',
#  'Part of hand removed by shark he had caught PROVOKED INCIDENT',
#  'Lacerations to knee & left lower leg by electrocuted captive shark PROVOKED INCIDENT',
#  'Injuries to head & torso',
#  'Lower limbs & thigh bitten',
#  'Fingers lacerated',
#  'Minor injury to lower leg and foot',
#  'No attack, no injury, shark took speared fish & approached diver closely ',
#  '3 small punctures on arm',
#  'Partial hominid remains recovered from shark, probable drowning and scavenging',
#  'Lower left leg & ankle bitten',
#  'FATAL, both legs severed ',
#  'Lacerations to right ankle, foot & toe',
#  'Minor laceration to left foot',
#  'Left eg bitten PROVOKED INCIDENT',
#  'Thigh severely lacerated, shin & calf lacerated',
#  'Speared shark bit his forearm PROVOKED INCIDENT',
#  'Shoulder abraded by skin of shark',
#  '7 puncture wounds in right forearm from hooked shark PROVOKED INCIDENT',
#  'Left arm and leg injured',
#  'No injury to occupants. Gaffed shark capsized boat PROVOKED INCIDENT',
#  'Survivors on life rafts were harassed by sharks',
#  'Puncture wounds & scratches to torso & left leg ',
#  'Right shin, calf and sole of foot lacerated',
#  'No injury to occupant, shark bit boat',
#  'Fell off board when spinner shark leapt from the water next to him. No injury to surfer',
#  "Human remains & clothing found in 7' shark",
#  '32 survived, 5 perished; sharks fed on the dead but did not bite the survivors',
#  'Head mouthed by captive shark PROVOKED INCIDENT',
#  'Punctures & lacerations on lower leg',
#  'Left hand punctured & lacerated',
#  'Right hand and wrist lacerated',
#  'Landed shark in boat bit his left leg  PROVOKED INCIDENT',
#  'No injury to occupants, hooked shark dragged boat 2 miles PROVOKED INCIDENT',
#  'Lacerations to left hand and forearm',
#  'No injury, shark bit paddle and stern of boat',
#  'Scratches on right upper arm',
#  'Lacerations to face',
#  'No injury, shark charged & impaled itself on spear',
#  'No Injury, shark struck his board',
#  'Right arm severely lacerated',
#  'Collision / No injury, no attack',
#  'Probable drowning & scavenging. ',
#  'Lacerations to right hand by captive shark PROVOKED INCIDENT',
#  'No injury to occupants. They shot shark, then it capsized their skiff. PROVOKED INCIDENT',
#  'No injury to occupants, hull of ski bitten',
#  'Right leg bitten knee to foot, surgically amputated',
#  'Puncture wounds to dorsum of right foot',
#  'No injury; no attack',
#  'Right side of back / torso lacerated',
#  'No injury, bumped by shark',
#  'No injury to occupants; shark rammed, bit & sank boat ',
#  'Attempted to frighten shark by smacking water with paddle. Shark bit paddle.  No injury to surf-skier PROVOKED INCIDENT',
#  'After diver shot shark attempting to take his catch, shark bit right arm & tore wetsuit  PROVOKED INCIDENT',
#  'Punctures & deep scratches to foot & buttock',
#  'Ear, shoulder, arm, wrist & ear injured',
#  'Puncture wounds to lower left leg and ankle, shallow lacerations to foot, deep laceration to Achilles tendon',
#  'Calf bitten & both hands injured',
#  'FATAL, left  leg & forearm severed',
#  'No injury to occupants; shark circled boat repeatedly then rammed the vessel 3 times',
#  'No injury to occupant, netted shark rammed & bit boat PROVOKED INCIDENT',
#  'Details unknown, possibly a PROVOKED INCIDENT',
#  'Small lacerations to foot',
#  'Dorsum of foot lacerated & toe severed',
#  'Bitten on arms, hands & feet while awaiting rescue',
#  'FATAL, buttocks, ankle & right elbow bitten ',
#  'Limbs severed',
#  "Shark bit diver's sleeve after he patted it on the head PROVOKED INCIDENT",
#  'No injury, knocked off board by shark',
#  'Buttock removed',
#  "Human remains recovered from a 10' to 12' shark caught in a turtle net",
#  'Two fingers lost PROVOKED INCIDENT',
#  'No injury, shark bit off stern of kayak',
#  'Lacerations to 2 fingers of left hand',
#  'Multiple major Injuries',
#  'Minor injury, marks on board',
#  'Right thigh bitten',
#  'No injury, shark allegedly took his surfboard & slashed his wetsuit. Shark involvement questionable',
#  'Lacerations to right forearm after he poked the shark with his spear PROVOKED INCIDENT ',
#  'Laceration to thigh by captive shark PROVOKED INCIDENT',
#  'FATAL, disappeared while swimming  ',
#  'No injury, board broken in half',
#  "2' cut to dorsum of foot, 2 puncture wounds to sole",
#  'FATAL, right leg severed',
#  'No injury to occupants, rudder damaged by shark',
#  '5.5-inch laceration on calf',
#  'Bitten on hand and thigh',
#  'FATAL, right leg severed above knee, surgically amputated but died 9 days later ',
#  'No injury, shark lifted the boat 0.5 m out of the water',
#  'No injury to occupants, shark bit boat',
#  'Multiple bites to foot after jumping off surfboard onto shark PROVOKED INCIDENT',
#  'Right forearm & wrist lacerated',
#  'No injury, board damaged by shark',
#  '2 lacerations to the thigh',
#  'No injury, rammed by shark',
#  'Right foot & leg bitten, surgically amputated',
#  'No injury, shark became entangled in his surfboard leash',
#  '5" gash in foot',
#  'Lacerations to left calf and both feet ',
#  '6" gashes in foot & leg ',
#  'Superficial injuries to upper leg may have been caused by surfboard fin',
#  'Minor lacerations to forearm when he grabbed shark by its tail     PROVOKED INCIDENT',
#  'Left forearm & hand bitten, surgically amputated ',
#  'FATAL. "Shark tore him to pieces.',
#  'Skeletonized, but shark involvement may have occurred after death.',
#  'Laceration and 4 puncture wounds to left hand',
#  'FATAL ',
#  '5 survived  & 4 perished, but shark involvement not confirmed',
#  'Thumb & thigh lacerated',
#  'Laceration & puncture wounds to right flank & hip',
#  'Shark rammed boat PROVOKED INCIDENT',
#  'Right upper am, shoulder & back severely  bitten',
#  'Foot bruised, board dinged',
#  'Hand bitten',
#  'Abrasions & 11 teethmarks on right lower leg',
#  'Bumped by sharks',
#  'Left foot bitten after he accidentally stepped on the shark         PROVOKED INCIDENT ',
#  'Gash on ankle',
#  'Puncture wounds to leg',
#  'Puncture wounds to thigh, defense wounds  to hand',
#  'Lower leg bitten & foot severed, leg surgically amputated below knee',
#  'Right thigh and leg lacerated',
#  'No injury to occupants; shark ripped off fibreglass hull, swamping boat PROVOKED INCIDENT',
#  'Laceration to left ankle, heel and little toe',
#  'Lower right calf lacerated',
#  'Harassed by sharks but not injured by them',
#  'Toe bitten',
#  'No injury, shark rammed surfboard',
#  'Left hand & forearm lacerated',
#  'Lacerations to arm & leg',
#  'FATAL, severe injuries to both legs ',
#  'Left forearm & wrist bitten',
#  'Both feet lacerated',
#  'No injury, shark bit surfboard ',
#  'Leg bitten above ankle by hooked shark taken aboard skiboat PROVOKED INCIDENT',
#  '4 punctures in left foot',
#  'Finger bitten by hooked shark PROVOKED INCIDENT',
#  'Superficial laceration to shoulder',
#  'Left hand, foot severed &  left calf & arm bitten',
#  "No injury, shark bumped diver's face",
#  'Lacerations to right hand & knee',
#  'Left leg severely bitten, surgically amputated',
#  'No injury, shark collided with surfer & board',
#  'No Injury to occupant, shark holed and sank boat',
#  'Hand & wrist severely bitten',
#  "Gietel grabbed the shark's tail, the shark lacerated his right ankle PROVOKED INCIDENT",
#  'No injury, no attack, shark took fish from back of kayak',
#  'No Injury, shark charged surfski',
#  'Lacerations to left thigh and hip',
#  'Left forearm bitten ',
#  'Bitten on leg and groin',
#  'Right thigh & buttock bitten',
#  'Foot & ankle injured',
#  '4 lacerations above left ankle',
#  'No injury, but trouser leg shredded by shark',
#  'Lacerations to hip and leg',
#  'FATAL, both arms bitten ',
#  'Left forearm bitten, surgically amputated',
#  'Foot bitten when he kicked shark PROVOKED INCIDENT',
#  'Upper right thigh bitten',
#  'No injury to occupants, shark bumped boat',
#  ' Search party saw a large shark devour what appeared to be part of her body',
#  'Six puncture wounds on  leg',
#  'Fingers, hand & arm bitten',
#  'Lacerations to shoulder and left bicep',
#  'Remains recovered from 4 m, 420-kg, caught 13-Dec-1987k',
#  'FATAL, left thigh & knee bitten ',
#  'Left foot bitten',
#  'Lacerations to left index finger & thumb ',
#  'Disappeared. His ripped dive jacket was recovered',
#  'No injury to occupants, shark rammed boat, bit planks & sheared off copper rivet at stern of boat',
#  'Injured by teeth of a dead porbeagle shark he was tossing overboard.',
#  'Superficial laceration of left arm',
#  'Hooked shark bit stern  PROVOKED INCIDENT',
#  'Lacerations to arms & leg',
#  'Lower back & hand bitten',
#  'The two Malabagos were bitten by sharks but survived. The other occupants of the boat  were rescued.',
#  'Lacerations & punctures in left calf & ankle',
#  'Heel & ankle bitten',
#  'FATAL, hooked shark pulled him into the water PROVOKED INCIDENT',
#  'FATAL x 3',
#  'FATAL, taken by shark  ',
#  'Leg & feet lacerated',
#  'No injury to occupants, shark charged boat after being shot twice with pistol and speared PROVOKED INCIDENT',
#  'Right thigh gashed, swim fin torn',
#  'Shark involvement prior to death was not determined',
#  'Injuries to left thigh',
#  'FATAL, left leg severed',
#  'Superficial injuries to left foot & ankle',
#  'Right leg & left foot lacerated',
#  'Abrasions and cuts to sole of foot',
#  '"Mauled"',
#  'FATAL, body was not recovered',
#  'No injury, a 3 m blue shark merely snapped at the man.',
#  'Lacerations on left foot & hand',
#  'Leg & hands bitten',
#  'Possible drowning victim, remains retrieved from 400-lb shark caught by fishermen on 28-Apr-1976',
#  'Injuries to arm, shoulder & chest, took 2 days to reach hospital',
#  'No injury, shark rammed kayak repeatedly',
#  "No injury. No attack. 12' white shark appeared curious, not aggressive & departed when prodded by spear",
#  'Right heel lacerated & swim fin removed by shark',
#  'No injury to occupants, sharks bit chunks from boat',
#  'Puncture wound to torso. Reported as a bite by a leopard shark, the tooth fragment appears to be that of a bony fish',
#  "No injury to occupant, shark lifted canoe's outrigger",
#  "No injury, speared shark towed Gilles 200 yards & tore hole in diving suit, and hit Dowswell's back with its tail PROVOKED INCIDENT",
#  'Left hand  bitten',
#  'Survived, PROVOKED INCIDENT',
#  'Laceration to hand',
#  'FATAL, right forearm severed, lacerations from buttocks to heel L',
#  'FATAL, multiple injuries ',
#  'FATAL, hands & calf bitten  ',
#  'Lacerations to leg & hand shark PROVOKED INCIDENT',
#  '6-inch gash on right foot',
#  "Shark bit his leg after he grabbed its tail & wouldn't let go PROVOKED INCIDENT",
#  'Foot punctured',
#  'Lacerations to right ankle ',
#  "Speared shark bit diver's right knee, and lacerated right thigh & buttocks PROVOKED INCIDENT",
#  'Foot bitten, tendons damaged',
#  "Speared shark bit Davy's ankle &  Pierpont's right leg  PROVOKED INCIDENT",
#  'Laceration to right calf',
#  'Dorsum of right foot grazed',
#  'No injury to occupant, shark took hooked fish then bit stern of boat',
#  'Both thighs were lacerated, recovered at Thursday Island hospital',
#  'Left thigh & calf lacerated',
#  'Laceration across abdomen',
#  'Knee bitten by shark that his dive buddy had shot  PROVOKED INCIDENT',
#  "After biting Halverson, it bit Scott's thigh",
#  'Severe abrasion to left lateral calf',
#  'Minor lacerations to heel',
#  'Flexed right  knee bitten',
#  'Calf lacerated',
#  '"lost part of a finger"',
#  'Bumped, chest bitten & badly injured',
#  'Arm severely lacerated by shark that had been hooked and shot PROVOKED INCIDENT',
#  'Disappeared 15 minutes into shallow dive. Decapitated body minus arm found by divers the following morning, then a large tiger shark appeared and consumed most of remains',
#  'Cause of death most likely drowning, remains recovered in shark',
#  'Minor injuries: scratches on nose & ankle. Board broken in two',
#  'Possible drowning / post mortem scavenging by Zambesi shark',
#  'Right lower leg and foot bitten',
#  'Lower left leg severely bitten',
#  'No injury, shark bit rail of foam board',
#  'Minor lacerations to left calf',
#  'No injury to occupants, shark bumped & lifted dinghy',
#  'Shark scavenged on his corpse',
#  'Leg lacerated FATAL',
#  'Bitten on calf by hooked shark PROVOKED INCIDENT',
#  'Arm & left calf bitten, right leg lacerated',
#  'Lacerations & punctures to left foot',
#  'Lacerations to left forearm. Lacerations to left hand and thigh',
#  'Presumed FATAL',
#  'Puncture to left hand',
#  'Left arm & right hand severed, lacerations to both legs',
#  'FATAL, decapitated and arm severed',
#  'FATAL x 6',
#  'FATAL, left arm & leg severed  ',
#  'No Injury',
#  'Right leg was bitten above and below the knee and an artery was punctured',
#  'Shoulder & arm bitten',
#  'Leg severed at knee',
#  'Lacerations to 2 fingers, but shark involvement unconfirmed',
#  'Badly bitten by a shark dragged onboard PROVOKED INCIDENT',
#  'Shallow lacerations on back of right thigh',
#  'FATAL, right hand severed, lacerations on left thigh & left hand, died in hospital of gas gangrene',
#  'Shark following hooked fish, rammed & holed boat',
#  'Fingers badly lacerated, wounds became septic',
#  'Right foot lacerated ',
#  'No injury, swim fin bitten',
#  'No injury, paddleboard bitten',
#  'Laceration to right foot when he struck a shark PROVOKED INCIDENT',
#  'Left thigh abraded, right knee and right index finger injured',
#  'It was believed that survivors were killed by sharks',
#  'No injury to occupants; shark struck their boat',
#  '2 bites behind knee',
#  'Shark attacked his boat, threatening to capsize it. He jumped overboard & shark bit his arm. He knifed & killed shark. Later his arm was surgically amputated',
#  'Sharks scavenged on bodies, but no record of them injuring survivors ',
#  'FATAL, attacked by shark, body not recovered ',
#  'Speared shark bit his hand PROVOKED INCIDENT',
#  'Pulled off board by shark but no injury',
#  'Leg abraded',
#  'Suffered from shock & immersion after being dragged underwater  by speared shark PROVOKED INCIDENT',
#  'Lacerations to left calf and ankle',
#  'Leg bitten, defense wounds on hands',
#  'Kneecap removed',
#  'Lower leg bitten, surgically amputated',
#  'Laceration to forearm by boated shark PROVOKED INCIDENT',
#  'Shark bit right arm & shoulder, then Aken says, he "knocked out" the shark',
#  "Man's leg recovered from 800-lb shark",
#  'FATAL, right leg, thighs & hands bitten  ',
#  "Whelan's head was injured when he fell to the deck as shark rammed boat",
#  "No injury, divers felt threatened by 10' pregnant female tiger shark & killed the shark",
#  '5 people killed by sharks, 30 others injured',
#  '9-inch gash in left foot ',
#  'Right shoulder & arm bitten',
#  'No injury, white shark struck platform',
#  'FATAL  (Wire netting installed at local beaches after this incident.)',
#  'Puncture wounds to left leg',
#  'Thigh bitten, FATAL',
#  'No injury, surf ski bitten',
#  'Netted shark made a5-inch incision above the knee PROVOKED INCIDENT',
#  'Minor injury to left forearm  PROVOKED INCIDENT',
#  'No injury to occupants, toothmarks on bottom & side of dinghy',
#  'Tissue of right thigh removed to the bone, both thumbs & some fingers severed ',
#  'No injury to occupants; oar bitten',
#  'Lacerations to leg  PROVOKED INCIDENT',
#  'Ear lacerated, cuts on scalp, back, arm & shoulder ',
#  'No injury to surfer, but the nose of his board was broken',
#  'Small cuts on big & pinky toes of left foot',
#  'Lacerations & abrasions, board bitten in half',
#  '6" laceration to left forearm ',
#  'No inury, shark & board collided',
#  'Lacerations to left wrist',
#  'Body not recovered. 3 days later some of his equipment was found on seabed appeared damaged by a shark ',
#  'Right elbow & forearm lacerated  PROVOKED INCIDENT',
#  'No inury',
#  'Thigh lacerated & abraded  PROVOKED INCIDENT',
#  'Right calf removed, leg surgically amputated below the knee',
#  'Right leg severely bitten',
#  'Bitten on thigh, abdomen & hand',
#  'No details, survived',
#  'No injury, knocked off board',
#  'Arm bitten',
#  "3.2 m [10.5'] shark caught 9 days later contained human remains thought to be those of Canham",
#  'No injury to occupants, kayak bumped by shark',
#  'Minor injuries to foot & toes',
#  'Tooth imprints on torso',
#  'No injury to occupants; shark leapt into boat, almost capsizing it and destroyed the inside of the boat',
#  'Lacerations to right arm & chest',
#  'Laceration to arm.',
#  'Minor injuries to legs',
#  'Puncture wound to finger',
#  'FATAL, left leg severed, right leg injured  ',
#  'Injuries to arm & leg by hooked shark   PROVOKED INCIDENT',
#  'Minor cuts on right heel & foot',
#  'Right foot bruised, board bitten',
#  'Disappeared & his torn clothing washed ashore',
#  'Hooked shark bit boat PROVOKED INCIDENT',
#  'Severe lacerations to thigh',
#  'FATAL, thigh bitten, femoral artery severed  ',
#  'No injury, shark bit boot',
#  'Punctures to left foot/ankle',
#  'Bitten on face while taking shark off spear PROVOKED INCIDENT',
#  'Lacerations to right  arm',
#  'Leg bitten ',
#  '3 wounds on left hand',
#  'Left leg bitten, surgically amputated',
#  'Left ankle & foot bitten',
#  'No injury to occupants, shark shook boat "stem to stern"',
#  'Severe lacerations to right leg',
#  'Leg severed FATAL',
#  'FATAL. Womack was injured when plane went down, 3 days later he fell off liferaft & was taken by a shark  ',
#  'Lacerations to right lower leg & left arm and hand',
#  'FATAL, taken by shark, body not recovered. Twenty months later, in October 1937, meshing (setting anti-shark gill nets) began  at metropolitan beaches',
#  'No injury, surfboard dented',
#  'Hooked shark gashed right leg      PROVOKED INCIDENT',
#  '"He was taken up alive and but little injured." ',
#  'Leg pinched',
#  'Arm bitten when he grabbed shark\x92s tail  PROVOKED INCIDENT',
#  'Right forearm injured, mid-humeral amputation',
#  "No injury, shark became tangled in hose & towed him 100'",
#  "The hooked shark didn't cut his finger, he was injured by his line",
#  'No injury to occupants , shark nudged oars',
#  'Lacerations to abdomen',
#  ' 2 of the 5 fishermen were so seriously injured they died of their wounds',
#  'Right ankle & lower leg lacerated',
#  "FATAL, victim seen in shark's mouth",
#  "Torso bitten by 4 m [13'] white shark",
#  '5 punctures to hand from captive shark PROVOKED INCIDENT',
#  'No injury to occupants, but shark struck boat with such force that Chandler was flung overboard. PROVOKED INCIDENT',
#  'Multiple injuries from boated shark PROVOKED INCIDENT',
#  'No injury, board bitten',
#  'Face bruised when partly blind shark collided with him',
#  'Minor injuries to hand & arm ',
#  'Bitten between left ankle & knee',
#  'Shark struck him with its tail',
#  'Severe abdominal wounds FATAL (Note: 14 days earlier a dog was bitten in two by a large shark)',
#  '3 puncture wounds to posterior right ankle',
#  '2-inch laceration on dorsum of foot, 1-inch laceration on sole.',
#  'Disappeared while fishing from shore. Leg found 7 days later wedged in rocks 150 yards offshore',
#  'FATAL, abdomen, buttock & thigh lacerated  ',
#  'Abrasion to right hand, lacerations to left forearm',
#  'FATAL, back of thigh bitten ',
#  'FATAL, shark bit his side, nearly cutting him in two  ',
#  'Lacerations to thigh & torso',
#  'Bodies of 5 of the 6 men on board were bitten by by sharks. Sharks may have contributed to the death of some of them.',
#  'Right arm bitten',
#  'No injury to occupants, boat scratched by shark',
#  'Lacerations knee to ankle',
#  'Severe lacerations to right buttock',
#  'Multiple bites to right arm',
#  'Shark bit his arm, nearly severing it PROVOKED INCIDENT',
#  'No injury. Diver shot shark, then shark tore legs of his rubber suit, water poured in & swept out to sea by strong rip current PROVOKED INCIDENT',
#  'No injury to occupant, shark charged boat',
#  'Minor cuts & bruises on face & neck',
#  "No injury to occupant, hooked shark bit boat's rudder PROVOKED INCIDENT",
#  'Fatal or drowned & remains scavenged by shark',
#  'Fingers & surfboard injured',
#  'Severe laceration to left leg',
#  'No injury. Towed by speared shark PROVOKED INCIDENT',
#  'Arms & legs severed',
#  'Foot bitten, required 1 week hospitalization PROVOKED INCIDENT',
#  'Abrasions & board bitten',
#  'No injury to occupant. Shark tore chunk from canoe, then bumped 2 other canoes',
#  'Shark made 3 passes at him, lacerating his calf, shin and ankle ',
#  '1  survivor',
#  'Legs bitten  FATAL',
#  '4 small lacerations on lower right leg',
#  'Torso bitten ',
#  '2 life preservers had been bitten by sharks',
#  'Bruised in falling overboard as shark bumped boat',
#  'Abdomen lacerated, surfboard holed',
#  'FATAL, disappeared, partial remains of Selim was found, there was no trace of Dea Opre',
#  'Both legs bitten, one surgically amputated',
#  '3-inch laceration to right foot',
#  'Hamstring bitten',
#  'No injury to occupants. Shark chasing fish struck boat',
#  'Left calf bitten',
#  'Leg lacerated & punctured',
#  'Both thighs bitten',
#  'No survivors & a body sighted could not be recovered because of sharks',
#  'No injury to occupants; shark bit dinghy leaving tooth fragments in  its woodwork',
#  'Foot & swim fin punctured',
#  'Injuries to arm and shoulder',
#  'Hands, legs & buttocks lacerated',
#  'Inner thighs lacerated',
#  'No injury, shark took chunk out of surfboard',
#  'Lacerations to right foot and ankle',
#  'Arm bitten ',
#  'Back, buttocks, left hand & left side of face bitten',
#  'Harpooned shark, bit boat, causing it to ship water. Boat reached shore in sinking condition PROVOKED INCIDENT',
#  'Lacerations to left calf & ankle, puncture wounds to left foot',
#  'Speared shark broke outrigger of canoe throwing man into the water & shark bit his buttock PROVOKED INCIDENT',
#  'Fingernail pulled off ',
#  'FATAL, right leg bitten thigh to calf  ',
#  'Hand & foot bitten',
#  'FATAL, left leg  & shoulder bitten  ',
#  'Thigh bitten',
#  'Hand, arm & thigh bitten',
#  'Leg nipped by hooked shark PROVOKED INCIDENT',
#  'The body of one woman had been bitten by a shark but it is not known if she was alive at the time, the other woman disappeared',
#  'Sharks\x92s jaws snapped shut, lacerating his right hand PROVOKED INCIDENT',
#  'Thigh & both wrists lacerated',
#  'Of 160 people on board, >100 missing',
#  'When survivors werer rescued on 10/27/1944 by PC 623 there were many sharks in the area',
#  'Questionable. Recovered flight gear was "completely shredded by sharks" but pilot may have died when plane hit the water,',
#  'FATAL    Severe bite to right thigh',
#  'PROVOKED INCIDENT    Diver poked shark with spear, then shark bit his right foot',
#  'Cut to tip of finger by a captive shark PROVOKED INCIDENT',
#  'Left thigh bitten',
#  'FATAL Arm bitten',
#  'Right leg allegedly bitten by a bull shark',
#  'Hip, leg, arm, hand & shoulder bitten',
#  'No injury, 5 sharks bumped raft',
#  'FATAL, only 1 of her crew of 7 survived',
#  'No injury, shark bit his speargun after he used it to prod the shark PROVOKED INCIDENT',
#  'Right hand and foot severed',
#  'FATAL, right thigh bitten ',
#  'FATAL, disappeared, dive gear & clothing found with teethmarks, presumed taken by a shark  ',
#  'Minor lacerations to left leg. nitially reported as a shark bite, but involved a barracuda',
#  'Radius & ulna bared',
#  '8" laceration on left calf',
#  "No injury, captive shark attempted to bite diver's arm PROVOKED INCIDENTt",
#  'Thigh nipped, minor injury',
#  'Arm, hand, buttock, leg and thigh bitten',
#  'Right leg lacerated',
#  'Injuries caused by coral, not the  shark',
#  'Body not recovered FATAL',
#  'Jumped off cliff',
#  'Groin bitten',
#  'Buttocks & leg bitten',
#  'Upper left thigh & right foot bitten',
#  'No injury, repulsed shark',
#  'Hand & wrist bitten, tooth fragments in wound',
#  'Right foot lacerated by a larger shark. Lost several toes  PROVOKED INCIDENT',
#  'No injury, shark nudged boat and bit propeller',
#  'Probable drowning and scavenging',
#  'No injury to occupants, boat holed by shark',
#  'Buttock bitten & major leg wound',
#  'Minor injury to torso',
#  'No injury, wetsuit torn & board bitten',
#  'Calf removed, not known if he survived ',
#  'FATAL, left leg & calf bitten, leg surgically amputated ',
#  'FATAL         Bitten in two by shark that he molested with a knife. Buried at Batu Island.  PROVOKED INCIDENT',
#  'Injuries to right calf',
#  'Hips & thighs bitten',
#  'No injury to occupants -  shark became entangled in aft rudder',
#  'Coroner determined the man was killed by a boat propeller, not a tiger shark',
#  'Lacerations to calf',
#  "No injury to occupants, shark's teeth embedded in keel",
#  'No injury, pressure ding on surfboard',
#  'Hit by tail of speared shark, fell & hit head on rock & out cold for 30 minutes  PROVOKED INCIDENT',
#  'Lacerations to ankle & foot',
#  'Laceration to left leg',
#  'FATAL, tissue removed from abdomen & thigh  ',
#  'Severe injuries to right hand & right thigh. Right hand  surgically amputated & his right leg a week later',
#  'Severe lacerations to foot',
#  'FATAL, torso bitten',
#  'FATAL, "bitten in two"',
#  '5 minor puncture wounds to lower left leg',
#  'Shark jumped into cockpit',
#  'Buttock bitten, tissue removed',
#  "2.4 to 3 m [8' to 10'] oceanic whitetip shark  buzzed him. No attack, no injury",
#  'FATAL, lost a leg',
#  'Remains recovered from 2.7 m tiger shark, but shark involvement prior to death unknown',
#  'No injury, no attack, 1.8 m copper shark made threat displays',
#  'Minor bruises & abrasions on leg',
#  'Hand & right shoulder lacerated',
#  'Bitten on buttock & leg',
#  'Right arm nearly severed at shoulder, left wrist lacerated',
#  " The 2.9 m [9.5'] shark never made contact with him. No attack, no injury.",
#  'Legs bitten PROVOKED INCIDENT',
#  'Forearm, abdomen & upper leg lacerated',
#  'Hand & foot lacerated,  lower left leg severely bitten, necessitating surgical amputation',
#  'Thigh lacerated by hooked shark PROVOKED INCIDENT',
#  'No injury, shark grabbed his camera',
#  'Foot bitten, 8 stitches needed to repair the wound',
#  'Minor cuts to sole & toes of left foot',
#  'Shark leapt onboard & into fishwell, tossing a crew member, Pepino, in the sea',
#  'No injury to occupants, hooked shark, snapped at rudder & then attacked boat PROVOKED INCIDENT',
#  'Right arm severed, ankle severely bitten ',
#  '2 puncture wounds to leg',
#  "Leg severed. Injury originally thought due to boat's propeller",
#  'Minor bite on heel & swim fin bitten',
#  'Minor lacerations to hand, 15" crescent-shaped piece removed from surfboard',
#  'FATAL        Only 4 of the 18 on board were rescued, some of the missing were allegedly killed by sharks',
#  'Cheek bitten',
#  'Minor cut on finger',
#  'Ankle severely lacerated',
#  "No injury. Shark grazed canoe, snapped at a piece of mast being trailed in the water & followed it into 2' of water",
#  'Head bitten by netted shark PROVOKED INCIDENT',
#  'Lacerations to head',
#  'No injury to occupants, pontoon punctured',
#  'Left leg & lower right leg bitten, taken ashore with shark still grasping his leg',
#  'Foot bitten by hooked shark PROVOKED INCIDENT',
#  'Drowned, no shark involvement',
#  'No injury to occupants, shark holed  boat',
#  'Hand badly injured, right arm surgically amputated above wrist',
#  'Laceration to thigh, likely caused by surfboard fin',
#  'No injury, right swim fin bitten',
#  'No injury to occupants, two 5-foot observation windows shattered',
#  'Leg bitten. He survived',
#  'Shark jumped in boat, but no injury to occupants',
#  'Minor injury to left hand',
#  'Several broken ribs',
#  'Torso lacerated',
#  'Bones recovered by fishermen in 300-kg [662-lb] white shark\x92s gut',
#  "FATAL, lost consciousness at depth of 180'. Large sharks seen near partial remains of body",
#  'Foot lacerated Recorded as PROVOKED INCIDENT',
#  '4 fingers of left hand were lacerated by shark he had shot in the head PROVOKED INCIDENT',
#  'Tissue stripped knee to foot',
#  'Thumb & index finger of left hand severed',
#  'Small laceration to forearm from netted shark  PROVOKED INCIDENT',
#  'Bitten on legs',
#  '3 fingers bitten by hooked shark PROVOKED INCIDENT',
#  'FATAL, chest & leg bitten ',
#  'Shoulder injured',
#  '4 cuts to posterior calf',
#  'Right foot: Toes and back of foot, minor injury',
#  'No injury. Hull bitten, tooth fragment recovered',
#  'Hip & thigh bitten',
#  'No injury to diver but shark left 3 toothmarks in his helmet',
#  'Minor injury to foot',
#  'Right calf abraded',
#  'FATAL            Arm severed',
#  'Fatal x 2',
#  'Right arm  bitten',
#  'Arm bitten by hooked shark PROVOKED INCIDENT',
#  'Minor',
#  'Lacerations to toes',
#  'Calf & shin bitten  PROVOKED INCIDENT',
#  'No injury to occupants, shark rammed boat for 15 minutes',
#  'Of the 42 people on board, 5 died of exposure, others drowned or were taken by sharks, and survivors were rescued after spending 3 days in the water.',
#  'Left leg & right testicle bitten',
#  'Of the 1,429 people on board, only 448 survived. Sharks were attacking survivors as they were being rescued',
#  'Right calf lacerated',
#  'Forearm & fingers lacerated, teethmarks on wood',
#  'Lacerations to hip, thigh and knee',
#  'Severely bitten on heel, 20 others taken by sharks',
#  'FATAL, right thigh & calf bitten ',
#  'Leg bitten & surgically amputated',
#  'No injury to occupants; hooked shark slammed into side of boat PROVOKED INCIDENT',
#  'His remains were recovered from a shark caught by  the trawler Ho Tai No.12 in March 1988',
#  'FATAL, foot & part of other leg severed  ',
#  'Leg bitten by gaffed shark PROVOKED INCIDENT',
#  "Shark's tail broke his leg. PROVOKED INCIDENT",
#  'Shark involvement prior to death not confirmed',
#  'Left thigh abraded & 3 fingers lacerated',
#  '3 lacerations on leg',
#  'Left calf & heel bitten',
#  'Reports said a shark attacked the dinghy, but Vickery said it did not',
#  'Remains of soldier in uniform. Probable drowning & scavenging',
#  'Puncture wounds to right foot',
#  'FATAL, calf bitten, other leg severed below knee',
#  'Lacerations to right hand & wrist',
#  'No injury, said to have been attacked by shark but drove it away with a lobster hook',
#  'No injury, board bumped & fin damaged',
#  'No injury, shark rammed boat & bit motor',
#  'No Injury, bumped by shark',
#  'Left shoulder bitten by netted shark PROVOKED INCIDENT',
#  '4 irregular lacerated wounds on right arm',
#  'No injury to occupants. Shark charged boat, tore off rudder & tossed it air, then swam off with it',
#  'Minor injuries to left leg and hand',
#  'Right knee lacerated',
#  'No injury to occupants. After being prodded with an oar, shark struck bow and sank boat PROVOKED INCIDENT',
#  'Arm & leg bitten',
#  'FATAL, arm/shoulder severed ',
#  'Left forearm bitten PROVOKED INCIDENT',
#  'Recovered',
#  'No injury to occupants; shark grabbed oar, vaulted over scull',
#  'Leg bitten. FATAL',
#  'Calf & shin bitten ',
#  'No injury, 8 pressure dings in surboard',
#  'Right ankle & foot bitten',
#  'Injuries to arms & hands',
#  'No injury, ski damaged',
#  '106 bodies were recovered, some had been bitten by sharks',
#  'Leg & foot lacerated',
#  'Lacerations to fingers',
#  'FATAL & some of the survivors were bitten by sharks  ',
#  'Tip of finger amputated PROVOKED INCIDENT',
#  'FATAL, 101 people perished, including commander, Joseph Couailhac. Iit was reported that a \x93shoal of sharks circled  passengers in the water and dragged scores of people to their deaths\x94 Of the 61 survivors, many were injured by sharks',
#  'Torso and left buttock bitten',
#  'Laceration to toe',
#  'Significant injuries to lower legs',
#  'Lacerations to left leg & foot',
#  'Thigh, buttocks & lower back lacerated',
#  'Abdomen & thigh bitten',
#  'Minor lacerations to right hand',
#  'No injury to occupant, shark struck stern of boat',
#  'FATAL, all onboard were killed by sharks',
#  'No injury but shark bit SUP',
#  '2 lacerations on left thigh',
#  'FATAL, left leg severed  ',
#  'FATAL, left torso, buttocks, thigh & foot bitten ',
#  'Laceration to big toe',
#  'Laceration to left calf',
#  'FATAL, bitten on arms, chest & legs',
#  'Lacerations to  arm',
#  'Foot & leg bitten',
#  'Facial lacerations',
#  'FATAL, leg severed',
#  'Shark involvement probably post-mortem',
#  'No injury, shark removed piece of surfboard',
#  'Bitten below right knee by hooked shark pulled onboard skiboat PROVOKED INCIDENT',
#  'Drowned due to CO2 poisoning - Post Mortem scavanging by blue shark',
#  'No injury to occupant. Shark rammed bottom of the boat',
#  'Right foot bitten, left leg severed',
#  'Minor injury to elbow',
#  'Shark struck him on shoulder injuring skin under suit',
#  'Left thigh bitten, leg surgically amputated ',
#  'Righ thigh severely bitten',
#  'Bitten on leg',
#  'Thighs abraded, puncture wounds in dorsal surface of left hand',
#  'FATAL. His body not recovered',
#  'Hand bitten by speared shark PROVOKED INCIDENT ',
#  'No injury, shark grabbed his fish and chased him to the boat',
#  'Thigh lacerated, abrasions',
#  'Small puncture wounds and lacerations on right leg just below knee',
#  'non-fatal',
#  'FATAL, it was  thought  the surviving crew  were taken by sharks',
#  'No details, it was the year the first settlers came ashore in Holdfast Bay, Port Pirie',
#  'Rescue aircraft saw bodies in the water being bitten by sharks. One survivor saw a shark take off a man\x92s leg & another reported that the second cook was killed by a shark',
#  'FATAL, partial remains recovered',
#  'Lacerations to lower left leg, ankle & foot',
#  'No injury, kayak bitten',
#  'Foot injured ',
#  'FATAL, multiple injuries to both legs  ',
#  'Massive tissue damage of left arm',
#  'Swimfin & 2 wool socks removed by shark, suit torn',
#  'Minor lacerations on left hand',
#  'Lacerations to both hands while attempting to land a hooked shark PROVOKED INCIDENT',
#  'Forearm, upper thigh, knee & ankle lacerated',
#  'Puncture wounds on  right thigh',
#  'Lacerations & punctures to lower right leg',
#  'No injury & not on board. Board adrift when bitten by shark',
#  'Lower leg & foot lacerated',
#  'Legs severely bitten, surgically amputated',
#  'Calf scratched & chunk bitten from board',
#  'Left leg gashed knee to ankle',
#  'FATAL, abdomen bitten',
#  'Lacerations to forearm',
#  'No injury, punctures to swim fin',
#  'No injury to occupants, shark leapt into boat & bit cabin door',
#  'Struck by shark immediately before it bit Tanner (see below)',
#  'Lacerations to hands & right leg when he tried to pull shark from the water PROVOKED INCIDENT',
#  'Right thigh',
#  'FATAL, right leg severed above knee  ',
#  'Lacerations to right thigh & left foot',
#  'No injury, shark bumped ski',
#  'No injury, but shark removed the heel & part of his left shoe',
#  '3 men knocked to ground by harpooned shark PROVOKED INCIDENT',
#  'No injury to occupants, shark nudged and bit boat',
#  'Head & torso bitten',
#  'Minor laceration on left leg',
#  'Shoulder nipped',
#  'Thigh severely bitten, femur exposed & grooved',
#  "Suttie's lower abdomen was bitten, Murray disappeared (presumed drowned)",
#  'FATAL, abdomen & thigh bitten',
#  'Lacerations to hands and knee',
#  'Toe injured',
#  'FATAL  Autopsy report: bitten by shark while still alive',
#  'Severe lacerations to left foot',
#  'No injury, surfboard rammed',
#  'FATAL, lower thigh & knee severely lacerated ',
#  'Shoulder lacerated',
#  ' 3 unidentified bodies recovered (male, female & young girl) from gut of female  4.5 m [14\'9"]  white shark caught in fishing net. They may have drowned in tidal wave following earthquake ',
#  'Leg severely bitten, surgically amputated',
#  'FATAL, head, shoulder and arm severed, remains recovered at Munglinup Beach on 9/13/1995',
#  'Non-swimmer pulled off pier& into the water by a hooked shark PROVOKED INCIDENT',
#  'FATAL, right thigh severely bitten, right ankle lacerated ',
#  'Thigh & lower abdomen severely bitten',
#  'Right shin lacerated',
#  'No injury, wetsuit punctured',
#  'No injury but kayak dented',
#  'No injury, but shark damaged one of his swim fins',
#  'Abrasions PROVOKED ATTACK',
#  'Lacerations to hand & forearm',
#  'Scrape to right forearm. Frennet says inflicted by a blue shark, but authorities question shark involvement',
#  'Major injury to torso',
#  'Arm, shoulder & back bitten',
#  'Laceration to shin',
#  'Leg & board bitten',
#  'No injury, teethmarks in board & torn wetsuit',
#  'Small lacerations to bottom of right big toe',
#  'Hand bitten while landing shark PROVOKED INCIDENT',
#  'Right leg bitten below the knee, left ankle & foot lacerated',
#  'Posterior thigh bitten',
#  'FATAL, arm & leg severed ',
#  'No injury to occupants, shark crashed through windshield of boat',
#  'Thigh bruised & abraded',
#  'Laceration to left forearm from hooked shark PROVOKED INCIDENT',
#  'Sharks attacked sailors in the water, several survivors picked up',
#  "3 ribs broken by shark's tail",
#  'Arm injured by hook, not by a shark',
#  'Right arm & torso bitten',
#  'Feet injured',
#  "4 fingers severed by 'dead' shark. PROVOKED ACCIDENT",
#  'No injury to occupants; boat damaged',
#  'No injury, shark bit board',
#  'Lacerations to right hand & forearm',
#  'No injury, but the kayak was bitten by the shark',
#  'Leg severed at knee,  hand severed, arms, torso & buttock severely lacerated',
#  'Two 3-inch lacerations to right ankle',
#  'Minor lacerations to  toe',
#  'FATAL, knocked overboard by tail of shark & carried off by shark ',
#  'Left leg severely bitten',
#  'Bitten on left hand',
#  'No injury to occupant, shark grabbed anchor rope, pulling bow of boat downward & then bit bow of boat',
#  'No injury to occupants, shark made 20 to 30 rushes at dinghy',
#  'Death due to drowning. Shark bite may have been postmortem',
#  'Right leg bitten',
#  'No injury to occupants. Shark bit motor, lifting stern a half-metre out of the water',
#  'No injury, board broken in two',
#  '"Drowned, 2 days later his head was bitten off by a shark"',
#  'Left foot & ankle lacerated',
#  'Abrasions',
#  'minor injury to foot',
#  'Shark struck helmet, no injury',
#  'No injury to occupants, shark holed canoet',
#  'No injury to occupant',
#  'Missing, thought to have been taken by a shark',
#  'Lacerations to anterior left lower leg',
#  '2 small lacerations on left lower leg when he jumped off board and landed on the shark PROVOKED INCIDENT',
#  'FATAL, coroner\'s Verdict: "Death presumably through shark attack & drowning"',
#  'Right leg bitten thigh to heel',
#  '"Serious"',
#  'Left foot bitten PROVOKED INCIDENT',
#  'Big toe bitten',
#  'Swept out to sea, feared taken by shark',
#  'Lacerations to left ankle and foot',
#  'Forearm slashed wrist to elbow by hooked shark he was trying to club to death  PROVOKED INCIDENT',
#  'No injury to occupants, shark leapt on bow of boat',
#  'No injury, surfboard leash severed',
#  '5 puncture wounds to thigh',
#  'Minor injury from captive shark PROVOKED INCIDENT',
#  'No injury, ski bitten',
#  'FATAL, seen with arm in mouth of shark. Body not recovered.  ',
#  'Injuries to arm',
#  'Minor cuts, sufboard bitten',
#  'FATAL, groin bitten ',
#  'Hip abraded, right calf severely lacerated',
#  'Calf avulsed by shark he was holding by the tail PROVOKED INCIDENT',
#  'Foot severely injured',
#  'Lacerations to back & right leg',
#  'No injury, but according to Fosdyk, captain & crew were killed by sharks',
#  'FATAL, shark "bit off all lower parts of him up to the belly"',
#  'FATAL, hips & thigh bitten ',
#  'FATAL, leg bitten, foot partly severed ',
#  'FATAL, but shark involvement prior to death could not be determined',
#  'No injury, steel diving helmet bitten 3 times',
#  'Puncture wounds on heel, legs and buttocks',
#  'Right calf bitten & less serious injury to left foot',
#  'No injury to occupants, but Emmanuel "later died of shock in hospital"',
#  'Puncture wounds & 2-inch laceration to calf',
#  'Right foot severed & calf removed, leg  surgically amputated below the knee',
#  'Head, shoulder, arm lacerated. Recorded as PROVOKED INCIDENT',
#  'Leg severed above knee',
#  'Minor injuries to right leg',
#  'FATAL, left arm severed above elbow, lacerations on chest, right thumb severed, left thigh lacerated to bone, abrasions  ',
#  '1.5-inch laceration',
#  'Bites on legs & thighs',
#  "No injury to occupants, boat was bumped & lifted 2' out of the water by the shark",
#  'Abrasions to leg',
#  'Underside of board, fins and, harness were damaged, and left  hip, thigh and buttock sustained puncture wounds',
#  'Severe laceration to left buttock & thigh',
#  'Right leg severed',
#  'Right forearm severed surgically amputated above elbow',
#  '"Slight laceration to leg"',
#  'Arm bitten FATAL',
#  'Minor injury to leg',
#  'No injury, catapulted into the water & ski damage',
#  'Deep lacerations to calf & ankle',
#  'Shot shark, then it bit him. Puncture wounds on leg  PROVOKED INCIDENT',
#  'No injury to occupant; shark capsized boat',
#  'Human remains found in shark',
#  'Lacerations to both feet',
#  'Abrasions on lower leg',
#  '"Molested by shark that nibbled his bare feet",  rescued 30 hours later.',
#  'Speared shark bit his chest PROVOKED INCIDENT',
#  'Lacerations to 2 fingers & knuckles abraded',
#  "Board rammed by shark, skegs knocked loose & 5' strip of fiberglass torn off, thigh scratched by shark\x92s teeth",
#  'Puncture wounds to right hand',
#  'Speared shark bit his arm  between elbow and shoulder PROVOKED INCIDENT',
#  'Toothmarks in board & his swim trunks',
#  'Shin lacerated',
#  'FATAL. His back was bitten as he was being towed to ship by rescuer, Lieut (j.g.) Stanley Kurta, then the shark pulled him below the surface. ',
#  'No injury to occupants. Shark beat away with oar',
#  'Severe bite to right leg',
#  'Injuries to abdomen and arm',
#  'No injury, shark bit air mattress, deflating it',
#  'Puncture wounds to thigh',
#  'No injury to occupants, shark struck boats+K1581',
#  "Human remains recovered from 11' shark",
#  'Hands, forearm & left thigh lacerated, radial artery severed',
#  'Ankle & foot lacerated, defense wounds on hand',
#  'No injury to occupants; hooked shark tore out part of transom, bit skeg of motor and snapped the steel trace PROVOKED INCIDENT',
#  'Shark knocked him off surf-ski, he inhaled water & had to be resuscitated PROVOKED INCIDENT',
#  'Minor injury to finger, PROVOKED INCIDENT',
#  'Right leg severed at knee.  In 1796 he became Lord Mayor of London. In 1778 he commissioned  American artist, John Singleton Copley, to paint the incident: Watson and the Shark',
#  'Lacerations to right side of face',
#  'Lacerations to  foot',
#  'Torso bruised & abraded ',
#  'FATAL, both arms severed  ',
#  '33 crew & 92 passengers were lost, it was thought that some were killed by sharks  FATAL',
#  'Left arm severed below shoulder',
#  'Shark bit rudder & hull',
#  'No injury, sharks ripped net & bit boat PROVOKED INCIDENT',
#  'A "dead" shark grabbed by the tail bit his right torso PROVOKED INCIDENT',
#  '3 lacerated irregular wounds on anterior left thigh',
#  'Lacerations and abrasions to foot and ankle',
#  'FATAL  ',
#  'No injury, grabbed byshark after he pulled its tail PROVOKED INCIDENT',
#  'Left leg bitten  PROVOKED INCIDENT',
#  'Severely bitten by shark caught 30 minutes earlier  PROVOKED INCIDENT',
#  'No injury, shark bumped board flipping him into the water',
#  'No injury to occupants. Sharks continually followed the dinghy, and one smashed its rudder ',
#  'Injuries to torso, head and face',
#  'No injury, but kayak scraped & dented',
#  'Thigh  lacerated',
#  'Another diver shot shark, shark bit his left foream  PROVOKED INCIDENT',
#  '10 of the 15 people perished, bodies of some who drowned  were scavenged by sharks',
#  'Right forearm lacerated by speared shark PROVOKED INCIDENT',
#  'Shoulder bitten',
#  'No injury, kayaker fell in the water when kayak bitten by a shark',
#  'U.S. destroyer John W. Weeks, 6 miles offshore, demonstrating guns & bombs for Mexican officials was thought to have driven the shark into the shallows where it bit the bather before other bathers drove it away with sticks & clubs.',
#  'FATAL, abdomen, pelvis & leg bitten      ',
#  'Abrasions to legs',
#  'Lacerations to right  hand ',
#  'Bumped, then knee bitten',
#  'No injury but shark bit trolling motor & rammed boat',
#  'Lacerations and puncture wounds in right arm ',
#  'Hooked & gaffed shark bit his right elbow PROVOKED INCIDENT',
#  'FATAL  When James Coucom, the lone survivor, was rescued, "2 sharks were pounding on the dinghy"',
#  'No injury to occupants, 6 sharks charged boat',
#  'Probable drowning & scavenging',
#  'Lacerations on head & neck',
#  'No injury to surfer, board bitten',
#  'No Injury, surfboard bitten',
#  'Arms broken by hooked shark PROVOKED INCIDENT',
#  'Laceration to foot from dead shark PROVOKED INCIDENT',
#  'Arm severed at elbow',
#  'Cause of death may have been downing',
#  'Samoan missionary, Filemani, caught an 8\'6" shark after it had killed 1 man & 2 boys in space of few weeks',
#  'FATAL, arms & legs bitten, then drowned ',
#  '3 to 4 cm laceration on foot from hooked shark brought on board PROVOKED INCIDENT',
#  'Lacerations to leg & hand',
#  '2 inch laceration to left lower calf.',
#  '20 punctures in right foot',
#  'Knee bitten after diver poked shark PROVOKED INCIDENT',
#  'Left ankle & foot lacerated',
#  'Lacerations to right forearm ',
#  'Right arm & fingers lacerated',
#  'Left knee, lower leg & foot bitten',
#  'Minor lacerations to posterior lower leg',
#  'Bitten on thigh and buttocks',
#  'Non-fatal, treated at Misima Hospital',
#  'Shark involvement prior to death unconfirmed',
#  'No injury, bumped off board',
#  'FATAL, multiple injuries to both legs, feet & left arm  ',
#  'No injury to occupant. As engine started, shark hit boat, breaking one of boat\x92s ribs in 3 places & stoving in 2 planks',
#  'FATAL, right leg bitten ',
#  'FATAL, arm bitten by shark hauled on deck             PROVOKED INCIDENT',
#  'FATAL, shark/s bit him in two',
#  'Left ankle, calf, thigh and abdomen bitten',
#  'Ankle & foot lacerated',
#  'FATAL, disappeared, then shark caught with head and body of man, from waist down minus leg, in its gut',
#  ...}

# %%
#Clean Fatal column:
dict(df_attacks['Fatal (Y/N)'].value_counts())
# Out:
# {'N': 4293,
#  'Y': 1388,
#  'UNKNOWN': 71,
#  ' N': 7,
#  'M': 1,
#  '2017': 1,
#  'N ': 1,
#  'y': 1}

# %%
df_attacks['Fatal (Y/N)'] = df_attacks['Fatal (Y/N)'].replace({' N': 'N', 'M': 'N', '2017': 'Unknown', 'N ': 'N', 'y': 'Y',})
df_attacks['Fatal (Y/N)'].fillna('Unknown', inplace=True)
df_attacks['Fatal (Y/N)'] = df_attacks['Fatal (Y/N)'].str.title()
dict(df_attacks['Fatal (Y/N)'].value_counts())
# Out:
# {'N': 4302, 'Y': 1389, 'Unknown': 612}

# %%
### Clean age:

# %%
df_attacks.Age.unique()
# Out:
# array(['57', '11', '48', nan, '18', '52', '15', '12', '32', '10', '21',
#        '34', '30', '60', '33', '29', '54', '41', '37', '56', '19', '25',
#        '69', '38', '55', '35', '46', '45', '14', '40s', '28', '20', '24',
#        '26', '49', '22', '7', '31', '17', '40', '13', '42', '3', '8',
#        '50', '16', '82', '73', '20s', '68', '51', '39', '58', 'Teen',
#        '47', '61', '65', '36', '66', '43', '60s', '9', '72', '59', '6',
#        '27', '64', '23', '71', '44', '62', '63', '70', '18 months', '53',
#        '30s', '50s', 'teen', '77', '74', '28 & 26', '5', '86', '18 or 20',
#        '12 or 13', '46 & 34', '28, 23 & 30', 'Teens', '36 & 26',
#        '8 or 10', '84', '\xa0 ', ' ', '30 or 36', '6½', '21 & ?', '75',
#        '33 or 37', 'mid-30s', '23 & 20', ' 30', '7      &    31', ' 28',
#        '20?', "60's", '32 & 30', '16 to 18', '87', '67', 'Elderly',
#        'mid-20s', 'Ca. 33', '74 ', '45 ', '21 or 26', '20 ', '>50',
#        '18 to 22', 'adult', '9 & 12', '? & 19', '9 months', '25 to 35',
#        '23 & 26', '1', '(adult)', '33 & 37', '25 or 28',
#        '37, 67, 35, 27,  ? & 27', '21, 34,24 & 35', '30 & 32', '50 & 30',
#        '17 & 35', 'X', '"middle-age"', '13 or 18', '34 & 19', '33 & 26',
#        '2 to 3 months', 'MAKE LINE GREEN', ' 43', '81', '"young"',
#        '7 or 8', '78', '17 & 16', 'F', 'Both 11', '9 or 10', 'young',
#        '36 & 23', '  ', 'A.M.', '?    &   14', '10 or 12', '31 or 33',
#        '2½', '13 or 14'], dtype=object)

# %%
df_attacks['age'] = df_attacks.Age.str.extract(r'(\d+)')
df_attacks.age = df_attacks.age.astype(dtype='float')
df_attacks.age.unique()
# Out:
# array([57., 11., 48., nan, 18., 52., 15., 12., 32., 10., 21., 34., 30.,
#        60., 33., 29., 54., 41., 37., 56., 19., 25., 69., 38., 55., 35.,
#        46., 45., 14., 40., 28., 20., 24., 26., 49., 22.,  7., 31., 17.,
#        13., 42.,  3.,  8., 50., 16., 82., 73., 68., 51., 39., 58., 47.,
#        61., 65., 36., 66., 43.,  9., 72., 59.,  6., 27., 64., 23., 71.,
#        44., 62., 63., 70., 53., 77., 74.,  5., 86., 84., 75., 87., 67.,
#         1.,  2., 81., 78.])

# %%
#Clean species:

# %%
set(df_attacks['Species '])
# Out:
# {nan,
#  '2.5 to 3 m shark',
#  '"Blue whaler" (Galeolamna)',
#  ' Wobbegong shark, 1.6 to 1.8m ',
#  'Bull or tiger shark',
#  "1.5 m [5']  shark",
#  'Thought to involve a mako shark, but possibly a sea lion',
#  'White shark, 4 m to 5 m ',
#  "White shark, 5 m [16.5']",
#  "Thought to involve a >2 m [6.75'] bull shark",
#  "2' to 3' reef shark",
#  "White shark, 5 m to 6 m [16.5 to 20'] ",
#  'Wobbegong shark, 1.4 m [4\'6"] ',
#  " 6' to 8' shark",
#  "White shark, female, 14'",
#  "Thresher shark, 3.7 m [12'] ",
#  'Blue sharks',
#  '7-gill shark?',
#  '30-kg [66-lb] shark',
#  'Said to involve a white shark but shark involvement not confirmed',
#  "Tiger shark, 10' to 12' ",
#  "1.5 m to 1.8 m [5' to 6']  blacktip shark",
#  'Bull shark or lemon shark',
#  '1.8 m silky shark',
#  "Blacktip shark, 2 m [6.75'] ",
#  'Bull shark, 2.5 m',
#  "Goblin shark, 4.2'",
#  'Blacktip reef shark',
#  "White shark, 15' to 16'",
#  "Tiger shark, 4.3 m [14'], 3 tooth fragments retrieved from his wounds",
#  '2.4 m shark',
#  "Next morning a 3 m [10'] shark was caught that had Andrews' leg in its gut",
#  'Allegedly a 4 m tiger shark',
#  "Tiger shark, 3 to 4 m [10' to 13'] ",
#  "White shark, 14' to 16' ",
#  "0.9 m  [3'] shark",
#  'White shark, identified by tooth fragments in surfboard',
#  "Hammerhead shark, 1.5 m [5'] ",
#  "3 m [10'] shark",
#  " Sevengill  shark, 1.2 m [4'] ",
#  "Tiger shark, 14' ",
#  'A \x93small\x94 shark',
#  "2 m [6.75'] shark",
#  "Tiger shark, 13' ",
#  'Nurse shark, 1 m ',
#  'Zambesi shark',
#  '80-lb hooked shark',
#  "Nurse shark, 1.5 m [5']  identified by Dr. E. Clark on description of shark",
#  "Tiger shark, 4.3 m [14'] ",
#  'Small bull shark',
#  "Bull shark, 4' to 5' ",
#  'Shark involvement prior to death unconfired',
#  '3.3 m [10\'9"] shark',
#  "Blacktip reef shark, 1.5 m [5'] ",
#  'A bull shark, according to some of the divers on the boat',
#  'Mako shark, 125-lb ',
#  "76 cm [2.5'] carpet shark",
#  '250-lb "dog shark"',
#  'Blacktip reef shark, 1m',
#  "1.5 to 2 m [5' to 6.75'] shark",
#  'Nurse shark, 1m ',
#  'Bronze whaler shark, 2 m',
#  "6' to 8' bull shark",
#  'Possibly a small blacktip shark',
#  'Tiger shark, 4 m ',
#  '100-lb shark',
#  'White shark, 2 m',
#  "1.2 m to 1.5 m [4' to 5'] bull, sandbar or dusky shark",
#  '5 m to 6 m white shark',
#  "2.7 m [9'] silky shark",
#  "4 m to 5 m [13' to 16.5'] white shark",
#  "5 m to 5.5 m [16.5' to 18'] white shark",
#  'Bronze whaler shark, 2 m ',
#  "Tiger shark, 1.5 m to 1.8 m [5' to 6'] ",
#  "Tiger shark, 2.4 m 3.4 m [8' to 11']  ",
#  ">2.5 m [8.25'] white shark",
#  "White shark, 4.3 m [14']",
#  'Silvertip shark',
#  'Wobbegong, 2m',
#  '"grey-colored shark"',
#  'White shark, 4.8 m ',
#  'Lemon shark, 1.8 m [6\'] male, N. breviostris, identified by W.A. Stark II, later the same day a 6\'8" pregnant female lemon shark bit the bow of the boat',
#  'Spinner shark',
#  'Several sharks involved',
#  'Bull shark, 400-lb ',
#  "White shark, 9'",
#  "Wobbegong shark, 1.4 m [4.6'] ",
#  "2' to 3' juvenile shark",
#  "Wobbegong shark, 3' ",
#  'Raggedtooth shark, 1.3 m',
#  'White shark, 4.5m',
#  'Species unidentified',
#  "Tiger shark, 14'",
#  "Two 2.1 m [7'] sharks",
#  "Mako shark, 2 m [6.75'] ",
#  'White shark, 4.5 m  to 6 m [14\'9" to 20\'] according to witnesses',
#  'Bull shark, 4 m',
#  'small sharks',
#  '"A pack of 6 sharks"',
#  "1.2 m to 1.8 m [4' to 6'] shark",
#  "Bull shark, 5' ",
#  'Reported to involve a bull shark',
#  'Possibly a wobbegong',
#  "4.5 m to 5.5 m [15' to 18'] white shark",
#  'Raggedtooth shark, 2 m ',
#  'Shark involvement highly doubtful',
#  'Blacktip shark ',
#  'bull shark',
#  'Possibly white sharks',
#  "Tiger shark, 6'",
#  '5.7 m white shark',
#  '20 kg shark',
#  'Mako shark, 400-lb ',
#  ">2.4 m [8'] white shark",
#  'Raggedtooth shark, 100-lb ',
#  "1.8 m [6'] grey reef shark",
#  'Blue shark',
#  "White shark, 18' to 20'",
#  "4.9 m to 5.5 m [16' to 18'] white shark",
#  "Wobbegong shark, 4' ",
#  '4 m white shark',
#  'White shark or bronze whaler',
#  '1.4 m [4\'6"] blacktip shark',
#  'Raggedtooth shark ',
#  'Unknown, but the shark was caught and put on exhibition',
#  'Bull shark suspected due to freshwater habitat',
#  'Grey nurse shark',
#  '"a school of sharks"',
#  'Sandtiger shark, 2 m, male ',
#  "1.8 m [6'] bull shark",
#  'Sevengill shark',
#  'Blue shark, 2m ',
#  'Thresher shark',
#  "14' white shark",
#  "Mako shark, 3 m [10'] ",
#  'White shark, 2 m to 4 m [6\'9" to 13\'] ',
#  'Tiger sharks & bull sharks (20 sharks in all)',
#  '"a young shark"',
#  '2 m shark, possibly a bronze whaler',
#  "2.4 m [8'] whaler shark",
#  'Tiger shark, 8 to 12 feet',
#  "Tiger shark, 7'",
#  "Six Zambesi sharks seen to 1.5 m [5'] in length",
#  "Two sharks seen in vicinity: 2.4 m & 4.25 m  [8' & 14'] TL",
#  "2.1 m to 2.4 m  [7' to 8'] shark",
#  "Said to involve a Grey nurse shark 3.7 m [12'] ",
#  'Juvenile nurse shark',
#  'Reported as a shark attack, the story was a hoax',
#  "Tiger shark, 3.7 m [12']",
#  'Bull shark, 2.7 m ',
#  "1.5 m to 2 m [5' to 6.75'] Caribbean reef shark ",
#  'Possibly a juvenile blacktip shark',
#  "3.5 m [11.5']shark",
#  'Tawny nurse shark',
#  'Alleged to involve a white shark "with little yellow eyes"',
#  "White shark, 2.1 m [7']  based on tooth pattern",
#  "White shark, 3.5 m [11.5'], identified by W. I.  Follett on tooth fragments",
#  "White shark, >6'",
#  'Broadnose sevengill shark',
#  "According to Carlsmith, the shark's mouth was 3' wide",
#  "Nurse shark, 60 cm to 90 cm [2' to 3'] ",
#  'Raggedtooth shark, 150-kg',
#  '1.8 m grey shark',
#  "Tiger shark, 3.7 m [12'], (tooth fragment recovered from wound)",
#  'Grey reef shark. 2 m',
#  "2' to 3' shark",
#  "Mako shark, 1.9 m [6.5'] ",
#  "Lemon shark, 2.7 m [9'] ",
#  '3 sharks',
#  'Oceanic whitetip shark, 1.8 to 2 m',
#  "14' shark",
#  "4.5 m to 5.5 m [14.7' to 18'] white shark",
#  'Tiger shark',
#  "1.8 m [6'] shark ",
#  "3.7 m to 4.6 m [12' to 15'] shark",
#  "Blue shark 6'",
#  "Tiger shark, 10'  ",
#  "Grey nurse shark, 8'",
#  'White shark, according to witnesses',
#  "2.7 m  [9'] shark",
#  '8 sharks',
#  'Lemon shark, >1 m ',
#  "1' to 4' shark",
#  "Possibly a 1' to 3' blacktip or spinner shark",
#  "Grey nurse shark, 2.6 m [8.5']  ",
#  "2.5 m to 3 m [8.25' to 10']  white shark",
#  '"a very large shark"',
#  'Description of shark does not ring true',
#  'shark involvement not confirmed',
#  "5.5' to 6' shark",
#  "Wobbegong shark, 1.5 m [5'] ",
#  "5.5 m [18'] shark",
#  "Bull shark, 5'",
#  '"Attacked by a number of sharks"',
#  'Miami, a 60 cm blacktip  shark and two 60 cm bamboo catsharks',
#  "+3' shark",
#  "White shark, 4.3 m 4.9 m [14' to 16'] ",
#  "Bronze whaler shark, 2.5 m [8.25']  k",
#  'Reportedly: oceanic whitetip sharks, blue sharks, tiger sharks & bull sharks',
#  'Lemon shark ',
#  "Carpet shark, 5' ",
#  " Galapagos shark, 6'",
#  'Shovelnose guitarfish, adult male ',
#  "3.7 m [12'] white shark",
#  'Tiger shark, 2.3m ',
#  'Blue shark, 4.5 m [14\'9"]',
#  'Whtietip reef shark',
#  'Blacktip shark',
#  "Nurse shark, 1.1 m [3.5'] ",
#  'White shark, based on bite pattern',
#  "Mr. Burgess of ISAF announced the injury was the bite of a 1.8 m [6'], 2- to 3-year old white shark. Subsequent investigation revealed there was  no shark involvement in this incident",
#  "White shark, 3 m [10'], tooth fragment from wounds identified as that of a white shark",
#  "4.7 m [15.5'] shark",
#  "Moreno\x92s leg  & part of his swim suit found in 9' shark caught two hours after the attack. Identified as carcharhinid shark by L. Schultz & C. Limbaugh on photograph",
#  "Nurse shark, 0.9 m  [3'] ",
#  "2' to 3.5' shark",
#  'Oceanic whitetip shark x 2',
#  'No shark involvement',
#  "White shark, 4.3 m [14'] ",
#  'White shark, 160-kg [353-lb], identity confirmed by tooth pattern',
#  '3 m to 4 m shark',
#  "1.2 m [4'], possibly  larger shark",
#  'a small shark',
#  'Shark involvement not confirmed & highly unlikely',
#  'Shark involvement prior to death suspected but not confirmed',
#  "2.7 m [9']shark",
#  "Grey reef shark, 1.2 m [4'] ",
#  'White shark named \x93Spotty\x94',
#  '3.6 m  porbeagle shark',
#  'Tiger shark, 100 kg',
#  'Small shark with white-tipped dorsal fin',
#  "2 m to 2.5 m [6.75'  to 8.25'] shark",
#  "White shark, 11' to 12'",
#  "1.8 m to 2.4 m [6' to 8'] hammerhead shark",
#  "White shark, 2.5 m [8.25'] ",
#  'White shark, 6.5 m ',
#  '1.5 to 2 m shark',
#  "1,5 m [5'] Caribbean reef shark (Carcharhinus  perezi)",
#  "6' shark",
#  'Thought to involve a white, bull or tiger shark',
#  'White shark, 13\'10", 1320-lb female ',
#  "Nurse shark, 10' ",
#  'Angel shark, 1.2m ',
#  '13\'10" shark',
#  'White shark, 6 m',
#  "6' to 7' blacktip shark",
#  'said to involve an oceanic whitetip shark',
#  "White shark, 6m [20']",
#  '"juvenile shark"',
#  'Lemon shark, 1164 mm, immature male, identified by  V.G. Springer',
#  "Raggedtooth shark, 1.5 m [5'] ",
#  '200-lb shark',
#  'Possibly a lemon shark',
#  'Sand shark?',
#  "Sevengill shark, 14', was caught in the vicinity",
#  "small sharks'",
#  '2 m  "yellow belly" captive shark. Shark destroyed by aquarium staff next day',
#  "2.4 m to 3 m [8' to 10'] grey colored shark",
#  "4.4 m [14'] shark",
#  'Lemon shark',
#  "Tiger shark, 3.4 m [11'] ",
#  "3' to 4' shark",
#  'Blue pointer',
#  "Bull shark, 4 m [13'] ",
#  "Hammerhead shark, 2.4 m [8'], according to lifeguard Sam Barrows",
#  '5\'7" shark',
#  "1.8 m [6'] sandtiger shark",
#  "Lemon shark, 2.1  m to 2.4 m [7' to 8'] ",
#  'Shark involvement not confirmed; thought to be a barracuda bite',
#  "Less than 1.2 m [4']",
#  "Raggedtooth shark, 1.5 m [5'] (tooth fragment recovered)",
#  'Tiger shark, female',
#  'juvenile white shark',
#  'Shark involvement prior to death not confirmed',
#  'Wobbegongs',
#  "Tiger shark, 4.6 m [15'] ",
#  ' Bull shark, 2.5 m',
#  " Blacktip shark, C. maculipinnis. 1.9 m to 2.1 m [6.5' to 7'] ",
#  'Caribbean reef shark',
#  "Tiger shark, 1.5 m [5'] ",
#  'Zambesi shark, 4\'9"',
#  "2.1 m [7'] lemon shark or bull shark",
#  'White shark',
#  '3m shark, probably a smooth hound',
#  "Silky shark, 1.9 m [6.5']",
#  'Possibly a spinner shark',
#  "1.2 m [4'] spinner shark",
#  'Possibly a tiger shark',
#  "Bronze whaler shark, 3 m [10'], 200-lb",
#  "2'  shark",
#  "2.1 m [7'] shark, possibly a spinner shark",
#  'Nurse shark',
#  "White shark, 2.7 m to 3 m [9' to 10'] ",
#  "Caribbean reef shark, 1.2 m to 1.5 m [4' to 5'] ",
#  '3.5 m white shark, tooth fragments recovered',
#  "8' bull shark or Caribbean reef shark",
#  "1.8 m [6'] white shark",
#  '24" to 30" shark',
#  "7' to 8' shark",
#  "A 2' shark was seen in the area by witnesses",
#  'Tooth fragments recovered from hull',
#  'Tiger shark, 3m ',
#  '15* to 24" dog shark',
#  "1.5 m [5'] dusky shark",
#  'small blacktip shark',
#  'nurse shark',
#  '"sandshark"',
#  ' Raggedtooth shark, 2m',
#  "4.6 m [15'] shark",
#  'Bull shark, 1 m',
#  "Bull shark, 6' to 7'",
#  'Blacktip or spinner shark',
#  '2 to 3 m shark',
#  'Shark involvement prior to death still to be determined',
#  "Nurse shark, 3' ",
#  "Spinner shark, 6'",
#  '3 m shark',
#  "1.5 m to 2.1 m  [5' to 7'] shark",
#  'White shark, 5m to 6m',
#  'Unknown, but it was reported that a shark tooth was recovered from the wound',
#  "4' shark?",
#  'Bull shark, 1.3 m',
#  '2.8 m [9\'3"] whaler shark captured 3 days later with his remains in its gut',
#  "Spinner shark, 3' to 4' ",
#  "3.7 m [12'] shark ",
#  "Oceanic whitetip shark, 6'",
#  'Raggedtooth shark, 2 m [6\'9"] ',
#  "1.8 m to 2.4 m [6' to 8'] sharks, most were oceanic whitetip sharks",
#  "White shark, 2.7 m [9'] ",
#  "Caribbean reef shark, 7' to 8'",
#  '4.5 m [14\'9"] white shark',
#  "Nurse shark, 1.5 m [5'] ",
#  "Bull shark, 2.3 m [7.5'] ",
#  'White shark, 18 mm tooth fragment  recovered from the hull',
#  "White shark, 3.7 m [12'] ",
#  'Possibly a bull shark or tiger shark',
#  "White shark, 5' to 7'",
#  "White shark, 5 m [16.5'] ",
#  '6 m  white shark',
#  "Grey nurse shark, 1.5 m [5'] ",
#  "4 m [13'] white shark",
#  "Bronze whaler shark, 4' ",
#  '1.5 m white-tipped reef shark',
#  "Bronze whaler shark, 6'",
#  "White shark, 4 m [13'] rk",
#  'Tiger shark, 4.5 m [14\'9"]',
#  'said to involve 2.5 m hammerhead sharks',
#  "Bronze whaler shark, 1.8 m [6'] ",
#  '"a black-tipped shark"',
#  '>1 m shark',
#  "White shark, 4.3 m [14'] (or bronze whaler)",
#  "Nurse shark, 6'",
#  'Grey nurse shark, 3m',
#  "5' spinner shark",
#  "2.1 m [7'] sandtiger shark",
#  "Nurse shark, 0.94 m to 1.2 m [3' to 4'] ",
#  'Shark involvement prior to deaths was not confirmed',
#  'Zambesi shark?',
#  'Gray reef shark',
#  "1.5 m to 1.8 m [5' to 6'] sharks",
#  "Grey reef shark, 5' to 8' ",
#  'Tiger shark caught 6 days later with diver\x92s remains in its gut',
#  "White shark, 16' ",
#  '3 m white shark',
#  'White shark?',
#  "[4.5' to 5'] shark",
#  'small nurse shark',
#  " Grey nurse shark,  3 m [10'] ",
#  '1.8 m blacktip "reef" shark',
#  'White shark, 3.6 m [11\'9"] ',
#  "White shark, 7' to 8'",
#  "Tooth fragment of a white shark recovered. Authorities believed shark was 6 m [20']  total length",
#  "1.5 m [5'] blacktip shark",
#  "Tiger shark, 2.4 m to 3 m [8' to 10'] ",
#  "3.7 m to 4.3 m [12' to 14'] shark",
#  "2.1 m to 2.4 m [7' to 8'] shark",
#  'small shark',
#  "Tiger shark said to be 5 to 7 m [16.5' to 23'] ",
#  "White shark, 10'",
#  "1.8 m [6'] dogfish",
#  "12' to 14' shark",
#  'small blacktip shark?',
#  "White shark, 4 m [13'] ",
#  'Grey nurse shark, 2 m',
#  'White shark, 3m, seen in area and hooked 3 days later',
#  'Said to involve a 4.9 m [16\'] "red shark"',
#  "Possibly a 6' bull shark",
#  "3 m to 3.7 m [10' to 12'] shark",
#  '.5 m shark',
#  'Port Jackson shark, 1m',
#  "Thought to involve a 2.7 m [9'], 400-lb bull shark",
#  'Shark involvement prior to death unconfirmed',
#  "6 m [20'] shark",
#  "Grey nurse shark, 4' ",
#  'Hammerhead shark',
#  "White shark 4.9 m [16'] ",
#  'Questionable incident',
#  '> 3 m shark',
#  'Remains recovered from shark caught days later',
#  'Copper shark',
#  '4\' "ground shark"',
#  'Possibly a 3 m bull shark',
#  '5 m shark',
#  'Bull shark, 3.5 m',
#  'Blue or porbeagle shark',
#  'Oceanic whitetip shark, 2.5m, female',
#  "Possibly a 1.5 m [5'] blacktip shark",
#  'Grey nurse shark, 2.9 m [9\'6"] ',
#  '1,100-lb shark',
#  'Bronze whaler sharks x 3',
#  'C. leucas tooth fragment recovered from kayak',
#  "Raggedtooth shark, 2 m [6.75'] ",
#  "Tiger shark, 8' to 10' ",
#  "2.4 m  [8'] shark",
#  "2.7 m [9'] bull or lemon shark",
#  '1.8 m shark',
#  'Thought to involve a cookie cutter shark',
#  'Bronze whaler shark, 2.5m',
#  "9.5' shark?",
#  'Doubtful / Unconfirmed attack / Unable to verify in local records',
#  "3.7 m to 4.3 m [12' to 14'] white shark",
#  '5m shark',
#  "15' shark",
#  '2.13 m shark',
#  '2.6 m shark',
#  'Questionable Incident',
#  'Possibly a sand shark',
#  "White shark, 1.5 m [5'] k",
#  "3.7 m [12'] tiger shark",
#  "14' to 18'shark",
#  "Mako shark, 4.3 m [14']",
#  "White shark, 5 m to 6 m [16.5' to 20] ",
#  "Tiger shark, 15' female",
#  'Said to involve a 1 m  white shark, but thought  that it was more likely a blue shark',
#  '>6 m white shark, according to witnesses',
#  "Bronze whaler shark, 2.1 m [7'] shark",
#  "Possibly a 6' lemon shark",
#  'Thought to involve a blacktip shark',
#  "7' to 8' bull shark",
#  'Bronze whaler shark, 1.5 m ',
#  'Mako shark (tooth fragments recovered)',
#  'Nurse shark, 58", 34-lb ',
#  "White shark, 1.7 m [5.5']",
#  "2.1 to 2.4 m [7' to 8'] shark",
#  "Zambesi shark, 1.2 m [4'] ",
#  'White shark, 3.6 m,  420 kg male',
#  '2 m to 2.5 m shark',
#  "5' shark",
#  '1 m shark',
#  '"sand" shark',
#  "Tiger shark, 3 m to 4 m [10' to 13'] ",
#  'Raggedtooth shark, 1.96 m, 140-kg ',
#  'Tiger shark, 3.5 m, 250-lb female',
#  'Possibily a  1.5 to 2 m sandtiger shark',
#  "White shark, 3.7 m [12'], 500 to 500-kg [1,200 lb], identified by W. C. Shroeder based on tooth fragment ebedded in gunwale",
#  "1.5 m to 1.8 m  [5' to 6'] shark",
#  "1.8 m [6'] shark",
#  'Large tiger shark seen in the vicinity the following morning',
#  "Blacktip shark, 5' to 6'",
#  'Tiger shark, 3.5 m ',
#  "Bull shark, 1.8 m to 2.1 m [6' to 7'] ",
#  'Salmon shark',
#  "White shark, 12'",
#  "Bull shark, 4' to bull shark",
#  "Mako shark (aka bonito shark) 1.2 m [4'] ",
#  '2.8 m [9\'3"] white shark',
#  "Tiger shark, 1.8 m to 2.4 m [6' to 8'] ",
#  "1.7 m [5.5'] shark",
#  "Comrades saw shark's tail appear about 5' away",
#  "White shark, 4 to 5 m [13' to 16.5'] ",
#  "13' shark",
#  "Said to involve a 6 m to 7 m [20' to 23'] white shark",
#  "White shark, 5.5 m to 6 m [18' to 20']  ",
#  "Bull shark, 3' to 4'",
#  "5' thresher or blue shark. The shark  was killed following the incident",
#  '4.5 m to 5 m white shark',
#  "4' tp 5' shark",
#  "Tiger shark, 1.5 m [5']k",
#  'Possibly a hammerhead shark',
#  '18" to 24" shark',
#  "2.4 m [8']  shark",
#  'A small spinner shark',
#  "White shark, 3.5 m [11.5'], species identity confirmed by tooth fragment",
#  "Nurse shark, 2'",
#  "3.7 m [12'] shark & may have been another shark nearby",
#  '1 m "grey-colored" shark',
#  "1.5 m to 1.8 m [5' to 6'] \x93spear-eye\x94 shark ",
#  "[4' to 5']",
#  "White shark, 5.8 m [19'] ",
#  "Horn shar,k Heterodontus francisci, 1.2 m [4'] ",
#  "3.5' to 4.5' shark",
#  'Oceanic whitetip shar,; identified by Dr. W.C. Schoeder on photograph & Dr. L.P. L. Schultz on sketch by observer',
#  "Blacktip shark, 1.8 m to 2.1 m [6' to 7'] ",
#  "Bull shark, 2.7 m [9'] was captured & dragged on the sand where tissue taken from Eggink was found in its gut. Species identification  was made by S. Springer based on 4 photographs of the shark. ",
#  '4.5  m [14\'9"] shark',
#  "Wobbegong shark, 5' ",
#  "8' to 10' shark",
#  'White shark, 600-kg [1323-lb]',
#  'Thought to involve a tiger shark',
#  "White shark, 1.8 m to 2.1 m [6' to 7']  according to Shreuder and a witness",
#  "1.2 m [4'] hammerhead shark",
#  '"reef shark"',
#  "3' small spotted catshark, Scyliorhinus canicula",
#  "Zambesi shark, 1.7 m [5.5'] ",
#  "Bronze whaler shark, 3 m [10'] ",
#  'Tiger shark, 2.5 m',
#  '3.5 to 4 m shark',
#  'A large white shark was filmed by divers on a local wreck 2 days prior to the incident.',
#  "Tiger sharks, 2.4 m to 4.9 m [8' to 16'] ",
#  "Possibly a 5' to 6' sandtiger shark",
#  "Bronze whaler shark, 2 m to 3 m [6.75' to 10']  ",
#  "3.5 m [11.5']  white shark",
#  "Tiger shark, 3 m to 4.9 m [10' to 16'] ",
#  "5' to 6' spinner or bull shark",
#  '2 sharks involved',
#  "Oceanic whitetip shark, 7'",
#  '"A 2\' (0.6 m) brown shark"',
#  'Hammerhead shark.',
#  " Sandbar shark, 3' to 4'",
#  '68" shark',
#  "2 m [6.75'] shark, 200-kg shark T",
#  "Blacktip shark, 5' to 6' ",
#  "Raggedtooth shark, 1.2 m [4'] ",
#  'Bronze whaler shark, 4m',
#  "Bull shark, 7'",
#  '3- to 4-foot shark',
#  "1.8 m [6'] Caribbean reef shark",
#  'White shark, 3m to 4m',
#  'Spinner shark, 4 to 5 feet',
#  "Possibly a Bull shark, 3'",
#  "White shark, 2.4 m [8'] ",
#  "2.6 m [8.5'] shark",
#  '"gray shark"',
#  "3 m [10'] white shark (Tooth  recovered from boat)",
#  "Nurse shark, 2.1 m [7']  identified by Dr. E. Clark on color & tooth impressions",
#  'Mako shark, 3m',
#  '2m shark',
#  'Not a shark attack; it was a hoax',
#  'Zambezi shark (tooth fragments recovered)',
#  "White shark, 3 m to 5 m [10' to 15'] ",
#  'Blacktip or spinner shark?',
#  "4.3 m [14'] shark",
#  'reef shark?',
#  "Tiger shark, 2.4 m [8']",
#  '2\' "banjo shark"',
#  'White shark, 2.7 m [9\'1"], 750-lb ',
#  'Leopard shark',
#  "Tiger shark, 10' ",
#  "Bull shark, 2.4 m [8']",
#  "Grey nurse shark, 2.7 m [9'] ",
#  'White shark, 4 to 5 m',
#  "Reported to involve a 3.7 m [12'] shark, possibly a white shark",
#  "White shark, 5.5 m [18'] ",
#  "Hammerhead shark, 5' ",
#  '6 m, 600-kg shark',
#  "1.8 m to 2.4 m [6' to 8'] shark",
#  "3.5 m [11.5'] shark",
#  "Bull shark, 10'",
#  "Grey nurse shark, 11'",
#  'Carpet shark',
#  'Bronze whaler shark, 1.5m',
#  'Tiger shark & others',
#  "Zambesi shark, 1.8 m [6'] ",
#  '4.3 m shark',
#  'White shark, based on 2 teeth retrieved from rudder',
#  "Blue shark, 7'",
#  'Dusky shark, 1 m ',
#  "Carpet shark, 10' ",
#  'C. macrurus captured 48 hours after attack with tissue removed from man in its gut; species identified by G.P. Whitley,  reported as C. obscurus by  R. Steel',
#  'A pack of 6 sharks',
#  'White shark, 4.5 m [14\'9"] ',
#  "Tiger shark, 2.4 m to 3.7 m [8' to 12'] ",
#  "1.5 m to 1.8m [5' to 6'] shark",
#  'Spinner shark or blacktip shark',
#  "1.9 m [6.5'] bull shark",
#  'Blacktip reef shark pup',
#  "Grey nurse shark, 10' ",
#  'white shark',
#  'Fishermen recovered partial remains from shark a week later',
#  'Tiger shark, <2 m TL',
#  'White shark or thresher shark',
#  'Sevengill shark, 2.4 m',
#  'White shark tooth fragment recovered from ankle & identified by Dr. W. I. Follett',
#  "Thought to involve a 2.6 m [8.5'] white shark",
#  "White shark, 4 m to 5 m [13' to 16.5'] ",
#  "White shark, 4.4 m [14.5'] . ",
#  "Lemon shark, 9' ",
#  '193-lb shark',
#  'Whale shark',
#  'Grey nurse shark?',
#  'juvenile shark',
#  "White shark, 12' to 15' female",
#  '4.5 m & 5 m white shark ',
#  'Raggedtooth shark, 1 m ',
#  'Wobbegong shark?',
#  "Said to involve a 2.4 m [8'] hammerhead shark",
#  'Unknown',
#  '2 m to  3 m shark',
#  '"Dog shark"',
#  "White shark, 1.8 m [6'] ",
#  '"whiptail shark" (thresher shark?)',
#  "Said to be a 7.6 m [25'] shark",
#  'White shark, 2.5m ',
#  "1.8 m to 2.1 m [6' to 7']\xa0 Caribbean Reef Shark ",
#  'Questionable, 2m shark suspected',
#  "Nurse shark, 2.1 m [7']",
#  'White shark, 1600-lb female ',
#  '40 to 50 sharks attacked survivors in the water',
#  "8' white shark or 7-gill shark",
#  "4 m [13'], 590-kg white shark",
#  '2.5 oceanic whitetip shark',
#  '4 to 5 m white shark',
#  "2 m to 2.5 m [6.75'  to 8.25'] sixgill or sevengill shark",
#  '3+ m shark',
#  "14' to 16' white shark",
#  "3 m [10'] sharks",
#  '4 to 5m white shark',
#  'Cookiecutter shark',
#  "Raggedtooth shark, 1.2 m to 1.5 m [4' to 5'] ",
#  '"small brown-colored shark"',
#  "2.4 m [8'] shark, possibly a dusky shark",
#  "3 m [10'], 270- kg [595-lb] shark",
#  "1.5 to 1.8 m [5' to 6'] shark",
#  '1.5 m grey reef shark',
#  'White shark, 2.5 m',
#  "Sandtiger shark, 2.1 m [7'] ",
#  "2.7 m [9']  bull shark or Caribbean reef shark",
#  "1.5 m [5'] shark, probable bull shark",
#  'Said to involve a 1.5 m shark',
#  "Tiger shark, 0.9 m to 1.5 m [3' to 5'] ?",
#  "Porbeagle shark, 7'",
#  'Shark involvement prior to death could not be determined',
#  "1.2 m to 1.5 m [4' to 5'] hammerhead shark",
#  'Said to involve white shark, but species identify questionable',
#  'Bronze whaler',
#  '2 m shark, possibly a dusky or blacktip shark',
#  "3 m [10'] shark seen in vicinity",
#  'Grey reef shark',
#  "Tiger shark, 9' to 10' ",
#  "Possibly a 1.5 m [5'] blacktip or spinner shark",
#  "4 m [13'] shark",
#  'small blue shark',
#  "White shark, 11' to 13'",
#  "0.9 m [3']  shark",
#  "Bronze whaler shark, 2.4 m [8'] Identified by Clyde Buttery",
#  "Possibly a  1.8 m [6'] Zambezi shark",
#  "Porbeagle shark, 3 m [10']rk",
#  "3.5 m [11.5'] white shark",
#  "Bronze whaler shark, 4.6 m [15'] ",
#  "Nurse shark, 2.1 m [7'] ",
#  'White shark, 4.5 m [14\'9"], identity confirmed by witness & tooth pattern',
#  "4.3 m [14'], 1000-lb shark",
#  'Porbeagle shark',
#  "12' shark",
#  "White shark, 3.7 m to 4.6 m [12' to 15'] ",
#  "17' white shark",
#  "60 cm to 90 cm [2' to 3'] shark",
#  "2.7 m [9']  shark",
#  '3.5 m [11\'6"] shark captured',
#  "Caribbean reef shark, 4.5'",
#  '"Shark caught later"',
#  "106 cm [3.5']  shark",
#  '9-foot shark',
#  'Seven-gill shark',
#  "15'",
#  '1.2 m to 1.5 m [4\' to 5\'] "reef shark"',
#  "Thought to involve a 2 m [6.75'] grey nurse shark",
#  '7-gill shark',
#  '4.9 m white shark',
#  'Possibly a blacktip reef shark',
#  '"grey shark"',
#  "Shovelnose shark, 5'",
#  "White shark, 3 m to 3.7 m [10' to 12'] ",
#  'reef shark, 1m',
#  "White shark, 3.7 m [12']  according to witnesses",
#  "Tiger shark, 5' ",
#  '>1.6 m shark',
#  "2.6 m [8.5'] shark landed 2 hours later",
#  ">6 m [20'] white shark",
#  "On 11-Jan-1994, his remains washed ashore. A 2.4 m [8'] tiger shark thought to be involved",
#  "His hand was found in a 2.4 m [8'] tiger shark caught 1/5/1949",
#  "White shark, 5.5 m [18']",
#  "5 m to 6 m [16.5' to 20'] white shark",
#  'Shark involvement not confirmed; officials considered barracua',
#  "Possibly a 5' to 6' bull shark",
#  'Possiby white shark',
#  "Bull sharks to 1.5 m [5']  in length",
#  '"A small shark"',
#  'a "small slim brown shark"',
#  'White shark (tooth fragments recovered from hull of boat)',
#  "Oceanic whitetip shark,1.8 m [6'] ",
#  '"small sharks"',
#  "Hammerhead shark, 9' ",
#  '234-lb shark',
#  "1.2 m to 1.5 m [4' to 5'] shark",
#  "Blacktip shark, 4' to 5'",
#  'Bull shark, 2.5m',
#  'Dusky shark, 2m',
#  'small catsharks',
#  'Tiger shark, 4.8 m',
#  "White shark, 4.3 m [14'], (tooth fragment recovered)",
#  "1.8 m [6'] shark, species identity questionable",
#  "Blacktip shark, 2.4 m to 3 m [8' to 10'] ",
#  'Soupfin shark',
#  "Tiger shark, 4.6 m to 7.6 m [15' to 25'] ",
#  "Bull shark, 6' to 8'",
#  "2' shark",
#  "Mako shark, 14' ",
#  "White shark, 3 m [10']rk",
#  'Shark involvement questionable',
#  'White shark, 3 m',
#  "White shark, 4.9 m [16'] ",
#  'Bronze whaler shark?',
#  '3.7m  to 4.2 m white shark',
#  "Said to involve an 8' shark but more likely damage caused by debris",
#  "Nurse shark, 1.2 m [4'] ",
#  'Shark involvement not confirmed',
#  "Tiger shark, 12' ",
#  "Blue pointer, 11' ",
#  ' Bull shark, 1.2m ',
#  'Tiger shark, 3m',
#  'Possibly a juvenile blacktip or spinner shark',
#  "Tiger shark, 8' to 12'",
#  'White shark, 4.5 m ',
#  'A 10-year-old 94-pound pregnant blacktip reef shark',
#  'Survivors said 2 species of sharks were involved:  oceanic whitetip sharks and another species',
#  "1.2 m to 1.5 m [4.5' to 5'] shark",
#  'Salmon shark suspected, but unlikely',
#  'White shark, 2.5 m ',
#  'Bull shark, 1m ',
#  "7' to 8' shark ",
#  "White shark, 3.7 m [12']  ",
#  "White shark, 12', identity confirmed by tooth fragment, witness and photograph of captured shark ",
#  "3.4 m [11']  tiger shark & a 5' shark",
#  "1.8 m [6'] blacktip shark",
#  "White shark, 2.5 m [8.25'], an immature female, previously injured",
#  "Lemon shark, 9'",
#  "Blacktip shark, 4'",
#  '1.7 m shark',
#  "1.8 m [6'], 136-kg [300-lb] shark ",
#  'Possibly a broadnose 7-gill shark',
#  'Tiger shark, 12',
#  'White shark, 2.7 m',
#  "Blue pointer, 12'",
#  ' Tiger shark, 2.8m',
#  'White shark, 6m ',
#  'Raggedtooth shark',
#  "1.5 m to 2.1 m [5' to 7'] shark, possibly a mako shark",
#  "3 m to 4 m [10' to 13']  white shark",
#  'Mako shark, 100-lb',
#  "1.5 m [5'] Caribbean reef shark",
#  'Mako shark, 180-kg [397-lb]',
#  "3' shark, possibly  a blacktip or spinner shark",
#  "Longfin mako shark, 3.5 m [11.5'], 350-kg [772-lb] ",
#  'A large hammerhead shark',
#  '4.5 m shark',
#  '300- to 400-lb Zambesi shark',
#  'Injury believed caused by an eel, not a shark',
#  "Hammerhead shark, 5.2 m [17'] ",
#  'Blue pointers',
#  "Bronze whaler shark, 2.1 m [7'], a tooth was embedded in the speargun ",
#  'White shark, 3.5 m',
#  "White shark, 3.5 m [11.5']  male ",
#  '200 to 300 kg shark',
#  "1.5 m to 2 m [5' to 6.75'] shark",
#  "Two 1.2 m to 1.5 m [4' to 5'] sharks",
#  "7' silvertip shark",
#  "Said to involve a 6.5 m [21.5'] shark",
#  'Sandtiger shark',
#  'Bronze whaler shark, 3 m',
#  'A "small shark"',
#  "Bull shark, 5' to 7'",
#  '\xa0 ',
#  "White shark, 2.1 m [7'] ",
#  "Tiger shark, 3.7 m to 4.3 m  [12' to 14']",
#  "12' sandtiger shark",
#  ' a small shark',
#  "White shark, 5.5 m to 6 m [18' to 20'] ",
#  "Teeth in hull identified as those from a white shark 4.6 m [15'] in length",
#  "Tiger shark, 2.4 m to 2.7 m [8' to 9']  ",
#  'Basking shark',
#  "Possibly a 10' bull shark",
#  "9' shark",
#  'Thought to involve a porbeagle or mako shark',
#  "Lemon shark, 1.5 m [5'], identified  by the surfer",
#  "Tiger shark, 3 m to 3.7 m [10' to 12'] ",
#  'Tiger shark (pregnant)',
#  ">1.2 m [4'] tiger shark",
#  "Tiger shark, 2.5 m [8.25'] ",
#  'Wobbegong shark, 2 m ',
#  'Grey nurse shark, 1m ',
#  "12' tiger shark",
#  "3 m to 4.3 m [10' to 14'] shark",
#  'Most likely, a small shark',
#  'Lemon shark, 30-lb ',
#  "White shark, 5 m  to 6 m [16.5' to 20'] ",
#  "7.5' shark",
#  "Tiger shark, 13' female",
#  "Said to be 6.4 m [21'] shark",
#  'Possibly a blue shark',
#  ' ',
#  "1.8 m [6'] blacktip shark or Caribbean reef shark",
#  'Possibly a bronze whaler shark',
#  "Mako shark, 3 m to 4 m [10' to 13'] ",
#  "Shovelnose shark, 6 m [20'] ",
#  "1.8 m to 2.7 m [6' to 9'] shark",
#  'Reported to involve a white shark',
#  'Thought to involve bull sharks',
#  'Lemon shark pup',
#  'Raggedtooth shark, 2.5m ',
#  '70 kg shark',
#  'Raggedtooth shark, 1.5 m',
#  "Tiger shark, 4 m [13'] ?",
#  "2.1 m [7'], 90-kg shark",
#  '9\'2" white shark',
#  "Alleged to involve a White shark, 7.6 m [25'] ",
#  'Shark involvement suspected but not confirmed',
#  "Nurse shark, 1.8 m [6'] ",
#  "4 m to 5 m [13' to 16.5']  white shark ",
#  "60 cm to 90 cm [2' to 3'] blacktip or spinner shark",
#  '\x93small brown shark\x94',
#  'White shark, 3.5m ',
#  'White shark, 4 m',
#  'Bull shark, 1.5m ',
#  '6 m shark',
#  'A 6.5\' "blue-nosed shark"',
#  "Tiger shark, 8'",
#  "3' to 3.5' shark",
#  "Bronze whaler shark,  3m [10'] ",
#  "3' blacktip shark",
#  'White shark, 3m ',
#  'Lemon shark, 2.5m to 3m ',
#  "1.8 m [6'] Zambezi shark",
#  "3 m to 4 m [10' to 13'] shark",
#  "Tiger shark, 2.4 m to 2.7 m [8' to 9'] ",
#  "3'  shark",
#  ">1.8 m [6'] shark",
#  '4.5 m white shark',
#  '"A pack of sharks"',
#  "1.5 m to 1.8 m [5' to 6'] sandbar shark",
#  'Questionable incident - shark bite may have precipitated drowning',
#  "8' great hammerhead shark",
#  "Grey reef shark, 1.8 m [6'] grey reef shark, identified by Dr. L.P. L. Schultz based on photographs; identified as C. melanopterus by Stewart",
#  'Wobbegong shark ',
#  'No shark invovlement - it ws a publicity stunt',
#  'White shark, 3.9 to 4.2 m',
#  'Bull shark, 1.5',
#  'Oceanic whitetip shark, 2.5m ',
#  'Shark involvement prior to death was not confirmed',
#  'Possibly C. leucas',
#  '1.3 m [4\'3"] shark',
#  "Lemon shark, 4' to 5' ",
#  "1.2 m to 1.5 m [4' to 5']   shark",
#  "Blacktip shark, 2' ",
#  "6' blacktip shark",
#  "1.5 m [5'] shark",
#  "2.5 m [8.25'] shark",
#  'Said to involve 2 sharks',
#  "White shark, 6 m [20'] ",
#  'White shark, 2.5m',
#  " Bull shark, 5'",
#  'small hammerhead shark',
#  'Whitetip reef shark, 1m',
#  "White shark, 19'",
#  '"a blue shark"',
#  'Mako shark ',
#  'Shortfin mako shark, 175-lb ',
#  " Tiger shark, 3'",
#  "1.5 m to 1.8 m [5' to 6'] shark",
#  "Reef shark, 5'",
#  "6' shark, possibly a blactip or spinner shark",
#  'Tiger shark?',
#  "1.8 m [6'] reef shark - or a 2.1 m to 2.4 m [7' to 8'] grey-colored shark",
#  "White shark, 15'",
#  'Zambesi shark, 2 m [6\'9"] ',
#  "6 m [20']  shark",
#  "White shark, 4.9 m [16']",
#  '1.8 to 2 m C. albimarginatus',
#  'Questionable incident; reported as shark attack but thought to involve a pinniped instead ',
#  '"a dog shark"',
#  "Wobbegong shark, 4'",
#  'Thought to involve a 5.5 m white shark named Kong',
#  '90-kg "blackfin" shark',
#  "Bull shark, 6'",
#  "Spinner shark, 5'",
#  "6' to 8' shark, possibly a tiger shark",
#  "Nurse shark, 2' to 3' ",
#  "Blacktip shark, 1.8 m [6'] ",
#  "Thought to involve a 12' white shark",
#  'Juvenile white shark,  2.7 to 3.2 m',
#  "Raggedtooth shark, 50-kg [110-lb], 2 m [6.75'] gaffed ",
#  "Wobbegong shark, 1.8 m [6'] ",
#  'White shark (tooth fragments recovered)',
#  "16' shark",
#  "Lemon shark, 6' female ",
#  "Thought to involve a 2.4 m [8'] lemon shark; two 2.4 m lemon sharks caught within 100 yds of the site a week prior to & a week after this incident",
#  'Thought to involve a mako or grey nurse shark',
#  '"a large shark"',
#  'Thought to involve a bull shark',
#  'White shark, 5 m ',
#  'Thought to involve a white shark',
#  '2.5 m shark',
#  "Wobbegong shark, 1.2 m [4'] k",
#  "4' shark",
#  "Tiger shark, 2.5 m [8.25']",
#  "Tiger shark, 6' ",
#  "4m [13'] shark",
#  "Bull shark, 10' ",
#  'Tiger shark, 2m ',
#  '1m shark',
#  'White shark, 1,900-lb ',
#  " white shark, 15' ",
#  'Shark involvement unconfirmed',
#  'Wobbegong',
#  '4 m shark',
#  'Bull shark, 2 m',
#  "Dusky shark, 12' ",
#  'Bull shark, 2m',
#  ' reef shark, 1.8m',
#  "Said to involve a 7 m [23'] white shark",
#  "Blue shark, 1.8 m [6'] ",
#  "White shark, 16', 2,312-lb ",
#  "5 m [16.5'] shark",
#  '5m, 3500 kg female shark',
#  'Oceanic whitetip sharks were in the vicinity',
#  ' Tawney nurse shark, 1m',
#  "0.9 m to 1.2 m [3' to 4'] white shark",
#  'Lemon shark, 2 m [6\'9"]',
#  "White shark, 13'",
#  "Sevengill shark, 2.4 m [8'] ",
#  'blacktip or spinner shark',
#  "0.9 m to 1.2 m [3' to 4'] shark; Tooth fragment recovered from hand",
#  '100-kg [221-lb] dead blue shark',
#  '5 m to 7 m white shark',
#  "2 scalloped hammerhead sharks, 1.5 m & 1.8 m [5' & 6']",
#  'White shark x 2',
#  '1 m shark, possibly whitetip reef shark',
#  'Bronze whaler shark, a  juvenile ',
#  "3 m [10'] gaffed shark",
#  'White shark, 2.8 to 3 m ',
#  '"Shark had a very large girth"',
#  'Blue shark?',
#  "4' to 5' shark",
#  "Tiger shark, 3.7 m [12'] ",
#  'Raggedtooth shark, 2m',
#  "1.8 m [6'] grey-colored shark",
#  'Reported by media as shark attack, but shark involvement prior to death was not confirmed',
#  "5 m  [16.5'] white shark",
#  '1.8 m [6\'] "cocktail shark',
#  '"black tipped" shark',
#  'Bull shark, 3m female',
#  "Sandtiger shark  2'",
#  'unknown, possibly a white shark',
#  "1.2 m  [4'] shark",
#  "2.1 m [7'], 140-lb reef shark",
#  'White shark, 4.6 m',
#  'Lemon shark or sandtiger shark',
#  "Grey reef shark, 2 m [6.75'] ",
#  "60 cm [2'] captive shark",
#  "Bull shark, 12'",
#  'A small shark',
#  'Tiger shark, 3.9 m',
#  '1.6 m shark',
#  "Hammerhead shark, 1.8 m [6'] ",
#  'possibly a bull shark',
#  "3.7 m [12'] shark",
#  "2.5 m [8.25'] bull shark",
#  "12' to 18' shark",
#  "1.8 m to 2.4 m  [6' to 8'] shark",
#  'Blue Shark ',
#  "6' to 8' shark",
#  "Remains recovered from 5.5 m [18'] white shark",
#  "Bitten by several 1.8 m [6'] sharks",
#  "1.8 m [6'] blacktip shark or spinner shark",
#  '2.2 m shark',
#  'Broadnose sevengill shark, 1.5 m',
#  "12' to 14' white shark",
#  '1.8 m to 2 m [6\' to 6\'9"] shark',
#  "Tiger shark, 1.8 m [6']",
#  "2.7 m [9'] shark later captured by Mitchell-Hedges",
#  "2.1 m [7'] shark",
#  'a school of sharks',
#  "Tiger shark, 12' ?",
#  "Lemon shark, 4' ",
#  '136-kg [300-lb] shark',
#  "White shark, 12' ",
#  'Bronze whaler shark, 2 m to 3 m ',
#  "Nurse shark, 4'",
#  "1.2 m [4'] shark (spinner shark?)",
#  "Nurse shark, 10'",
#  'Blacktail reef shark',
#  "3.7 m [12'] sharks",
#  '"a small shark"',
#  'reef shark',
#  "5' to 8' shark",
#  "3 to 3.5 m [10' to 11.5'] bull shark",
#  "Mako shark, 1.9 m [6.5']. Tooth fragment recovered & identified by J.T. Nichols.",
#  'Juvenile dusky shark',
#  "Thought to involve a 3' to 4' shark, but shark involvement not confirmed",
#  "Sandtiger shark, 4' to 5'",
#  ...}

# %%
df_attacks['species'] = df_attacks['Species '].str.extract(r'(\w+ .hark)')
df_attacks.species = df_attacks.species.str.title()
df_attacks.species.fillna('Unknown', inplace=True)

# %%
shark_list = ['Young Shark',
 'Two Shark',
 'Unidentified Shark',
 'Unknown',
 'The Shark',
 'Small Shark',
 '1M Shark',
 '2 Shark',
 '2M Shark',
 '3 Shark',
 '30Kg Shark',
 '3M Shark',
 '50 Shark',
 '5M Shark',
 '6 Shark',
 '7 Shark',
 '8 Shark',
 'A Shark',
 'As Shark',
 'But Shark',
 'Another Shark',
 'As Shark',
 'But Shark',
 'Female Shark',
 'Foot Shark',
 'For Shark',
 'From Shark',
 'Kg Shark',
 'Large Shark',
 'Larger Shark',
 'Lb Shark',
 'M Shark',
 'No Shark',
 'Of Shark',
 'Same Shark']

# %%
df_attacks.species = df_attacks.species.replace(shark_list, 'Unknown')
df_attacks['species'] = df_attacks['species'].str.extract(r"(\w+[^\s'shark'])")
df_attacks['species'] = df_attacks['species'].replace({'Carcharhinid': 'Carcharhinidae', 'Carcharinid': 'Carcharhinidae', 'Dogfi' : 'Dog', 'Grey': 'Gray', 'Nose': 'Nosed','Sandb': 'Sand', 'Zambesi':'Zambezi'})
set(df_attacks.species)
# Out:
# {'Angel',
#  'Banjo',
#  'Basking',
#  'Blacktip',
#  'Blue',
#  'Bonit',
#  'Bonnethed',
#  'Brown',
#  'Bull',
#  'Captive',
#  'Carcharhinidae',
#  'Carpet',
#  'Cocktail',
#  'Colored',
#  'Cookiecutte',
#  'Coppe',
#  'Cow',
#  'Cutte',
#  'Dog',
#  'Dusky',
#  'Finned',
#  'Gaffed',
#  'Galapago',
#  'Gill',
#  'Goblin',
#  'Gray',
#  'Ground',
#  'Hammerhead',
#  'Hooked',
#  'Jackson',
#  'Juvenile',
#  'Lemon',
#  'Leopard',
#  'Little',
#  'Mako',
#  'Metre',
#  'Nosed',
#  'Nurse',
#  'Porbeagle',
#  'Raggedtoot',
#  'Red',
#  'Reef',
#  'Salmon',
#  'Sand',
#  'Sandtige',
#  'Saw',
#  'Sevengill',
#  'Several',
#  'Shovelnose',
#  'Silky',
#  'Silvertip',
#  'Smoothhound',
#  'Soupfin',
#  'Spinne',
#  'Threshe',
#  'Tige',
#  'Tipped',
#  'Unknown',
#  'Whale',
#  'Whiptail',
#  'White',
#  'Whitetip',
#  'Wobbegong',
#  'Zambezi'}

# %%
### ALL CATEGORIES HAVE BEEN CLEANED!

#Now drop the following columns:
"""
Location
Activity
Sex
Age
Injury
Time
Species
Name

""";

# %%
df_attacks = df_attacks.drop(['Activity', 'Sex ', 'Age', 'Injury', 'Time', 'Species ', 'Name'], axis=1)

# %%
#And set the new structure of the database:
"""
date = index
year
month
week_number
hour

*

Country
Area
Location

*

species
activity
Fatal (Y/N)
sex
age

*

Investigator or Source

""";

# %%
df_attacks = df_attacks.set_index('date')
df_attacks = df_attacks.rename(columns={'Country': 'country', 'Area': 'area', 'Location': 'location', 'Fatal (Y/N)': 'survived', 'Investigator or Source': 'source'})
df_attacks = df_attacks[['year', 'month', 'week_number', 'hour', 'country', 'area', 'location', 'species', 'activity', 'survived', 'sex', 'age', 'source']]

# %%
df_attacks.sample(10)
# Out:
#             year  month week_number  hour           country  \
# date
# 1930-07-11  1930      7          27   NaN     United States
# 2014-09-21  2014      9          38  11.0     United States
# 1924-10-18  1924     10          41   NaN         Australia
# 2007-03-31  2007      3          12  13.0     United States
# 1933-05-03  1933      5          18   NaN              Cuba
# 1971-04-16  1971      4          15   NaN             Kenya
# NaT         1964      7         NaN   NaN  Papua New Guinea
# 2014-10-12  2014     10          41  15.0     United States
# NaT         1898      0         NaN   NaN     United States
# 1955-08-30  1955      8          35   NaN             Japan
#
#                             area  \
# date
# 1930-07-11               Florida
# 2014-09-21               Florida
# 1924-10-18              Victoria
# 2007-03-31               Florida
# 1933-05-03       Havana Province
# 1971-04-16        Coast Province
# NaT         New Ireland Province
# 2014-10-12               Florida
# NaT                       Hawaii
# 1955-08-30           Izo Islands
#
#                                                      location  species  \
# date
# 1930-07-11                        Jensen Beach, Martin County     Tige
# 2014-09-21                   New Smyrna Beach, Volusia County  Unknown
# 1924-10-18                                     Port Melbourne  Unknown
# 2007-03-31  Waveland Beach, Hutchinson Island, St. Lucie C...  Unknown
# 1933-05-03                  Off Jaimanitas Yacht Club, Havana  Unknown
# 1971-04-16                                             Watamu  Unknown
# NaT                     A reef off New Hanover (Northern end)  Unknown
# 2014-10-12                    Melbourne Beach, Brevard County  Unknown
# NaT                                                       NaN  Unknown
# 1955-08-30       Mikura-jima Island, 150 miles south of Tokyo  Unknown
#
#             activity survived sex   age  \
# date
# 1930-07-11   Unknown        N   M  21.0
# 2014-09-21   Unknown        N   M   NaN
# 1924-10-18   Unknown        N   M   NaN
# 2007-03-31   Unknown        N   M   9.0
# 1933-05-03  Swimming        Y   M   NaN
# 1971-04-16   Unknown        N   M  16.0
# NaT         Standing        Y   M   NaN
# 2014-10-12   Surfing        N   F   NaN
# NaT          Unknown        Y   M   NaN
# 1955-08-30   Unknown        Y   M   NaN
#
#                                                        source
# date
# 1930-07-11  NY Times, 7/13/1930, Section II, p.1, col.7; R...
# 2014-09-21                               NBC2 News, 9/21/2014
# 1924-10-18   Coppleson.V1. (1933); Melbourne Herald, 1/7/1925
# 2007-03-31                         Palm Beach Post, 3/31/2007
# 1933-05-03                              NY Times, May 4, 1933
# 1971-04-16                                       M. v. Schoor
# NaT                       Times Courier (Lae, PNG) 7/29/1964
# 2014-10-12                          Florida Today, 10/13/2014
# NaT         H.W. McCurdy, History of the Pacific Northwest...
# 1955-08-30  K. Nakaya, L.A. Times, 8/31/1955; V.M. Copples...

# %%
df_attacks.to_csv('attacks_clean.csv')
